# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import re
import numpy as np
from nltk.stem import WordNetLemmatizer

# %%
messages = pd.read_csv('../data/spam.csv', encoding='latin-1', sep=',')
messages = messages[['v1', 'v2']]
messages = messages.rename(columns={ 'v1': 'label', 'v2': 'messages' })
messages
# Out:
#      label                                           messages
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# performing lemmatization
from nltk.stem import WordNetLemmatizer

# create a lemmatizer object
lemmatizer = WordNetLemmatizer()
lemma_corpus = []
for i in range(0, len(messages)):
    
	result = re.sub('[^a-zA-Z]', ' ', messages['messages'][i])
	result = result.lower() # convert to lower case
	# split the result
	result = result.split()

	result = [lemmatizer.lemmatize(word, pos='v') for word in result if word not in stopwords.words('english')]

	result = ' '.join(result)
	lemma_corpus.append(result)

# %%
# bag of words but with ngrams - UNIGRAM
# create new bag of words with lemmatizer 
lemma_cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(1, 1))
X = lemma_cv.fit_transform(lemma_corpus).toarray()
lemma_cv.vocabulary_
# Out:
# {'go': np.int64(870),
#  'point': np.int64(1574),
#  'crazy': np.int64(493),
#  'available': np.int64(186),
#  'bugis': np.int64(319),
#  'great': np.int64(898),
#  'world': np.int64(2427),
#  'la': np.int64(1137),
#  'cine': np.int64(413),
#  'get': np.int64(852),
#  'wat': np.int64(2334),
#  'ok': np.int64(1468),
#  'lar': np.int64(1145),
#  'joke': np.int64(1103),
#  'wif': np.int64(2385),
#  'oni': np.int64(1477),
#  'free': np.int64(781),
#  'entry': np.int64(656),
#  'wkly': np.int64(2413),
#  'comp': np.int64(446),
#  'win': np.int64(2391),
#  'cup': np.int64(506),
#  'final': np.int64(739),
#  'tkts': np.int64(2116),
#  'st': np.int64(1936),
#  'may': np.int64(1292),
#  'text': np.int64(2053),
#  'receive': np.int64(1681),
#  'question': np.int64(1644),
#  'std': np.int64(1947),
#  'txt': np.int64(2199),
#  'rate': np.int64(1662),
#  'apply': np.int64(132),
#  'dun': np.int64(618),
#  'say': np.int64(1772),
#  'early': np.int64(622),
#  'already': np.int64(85),
#  'nah': np.int64(1402),
#  'think': np.int64(2078),
#  'usf': np.int64(2262),
#  'live': np.int64(1204),
#  'around': np.int64(154),
#  'though': np.int64(2085),
#  'freemsg': np.int64(783),
#  'hey': np.int64(965),
#  'darling': np.int64(527),
#  'week': np.int64(2353),
#  'word': np.int64(2424),
#  'back': np.int64(202),
#  'like': np.int64(1188),
#  'fun': np.int64(805),
#  'still': np.int64(1951),
#  'tb': np.int64(2028),
#  'xxx': np.int64(2460),
#  'send': np.int64(1798),
#  'rcv': np.int64(1665),
#  'even': np.int64(670),
#  'brother': np.int64(310),
#  'speak': np.int64(1920),
#  'treat': np.int64(2171),
#  'aid': np.int64(59),
#  'per': np.int64(1527),
#  'request': np.int64(1714),
#  'melle': np.int64(1307),
#  'oru': np.int64(1494),
#  'minnaminunginte': np.int64(1328),
#  'nurungu': np.int64(1454),
#  'vettam': np.int64(2282),
#  'set': np.int64(1809),
#  'callertune': np.int64(343),
#  'callers': np.int64(342),
#  'press': np.int64(1605),
#  'copy': np.int64(475),
#  'friends': np.int64(791),
#  'winner': np.int64(2398),
#  'value': np.int64(2274),
#  'network': np.int64(1420),
#  'customer': np.int64(511),
#  'select': np.int64(1792),
#  'prize': np.int64(1614),
#  'reward': np.int64(1728),
#  'claim': np.int64(417),
#  'call': np.int64(338),
#  'code': np.int64(431),
#  'valid': np.int64(2272),
#  'hours': np.int64(1000),
#  'mobile': np.int64(1345),
#  'months': np.int64(1364),
#  'entitle': np.int64(655),
#  'update': np.int64(2241),
#  'latest': np.int64(1150),
#  'colour': np.int64(439),
#  'mobiles': np.int64(1346),
#  'camera': np.int64(347),
#  'co': np.int64(429),
#  'gonna': np.int64(875),
#  'home': np.int64(985),
#  'soon': np.int64(1905),
#  'want': np.int64(2327),
#  'talk': np.int64(2021),
#  'stuff': np.int64(1970),
#  'anymore': np.int64(116),
#  'tonight': np.int64(2140),
#  'cry': np.int64(500),
#  'enough': np.int64(653),
#  'today': np.int64(2127),
#  'six': np.int64(1863),
#  'chance': np.int64(384),
#  'cash': np.int64(367),
#  'pound': np.int64(1590),
#  'cost': np.int64(479),
#  'day': np.int64(532),
#  'days': np.int64(533),
#  'tsandcs': np.int64(2183),
#  'reply': np.int64(1711),
#  'hl': np.int64(975),
#  'info': np.int64(1050),
#  'urgent': np.int64(2250),
#  'membership': np.int64(1310),
#  'www': np.int64(2451),
#  'net': np.int64(1418),
#  'pobox': np.int64(1571),
#  'ldnw': np.int64(1158),
#  'search': np.int64(1784),
#  'right': np.int64(1731),
#  'thank': np.int64(2065),
#  'promise': np.int64(1624),
#  'wont': np.int64(2423),
#  'take': np.int64(2018),
#  'help': np.int64(964),
#  'wonderful': np.int64(2422),
#  'bless': np.int64(270),
#  'time': np.int64(2107),
#  'date': np.int64(530),
#  'sunday': np.int64(1989),
#  'use': np.int64(2259),
#  'credit': np.int64(496),
#  'click': np.int64(421),
#  'wap': np.int64(2328),
#  'link': np.int64(1194),
#  'next': np.int64(1426),
#  'message': np.int64(1315),
#  'http': np.int64(1008),
#  'com': np.int64(440),
#  'oh': np.int64(1466),
#  'watch': np.int64(2335),
#  'eh': np.int64(634),
#  'remember': np.int64(1701),
#  'spell': np.int64(1925),
#  'name': np.int64(1404),
#  'yes': np.int64(2480),
#  'naughty': np.int64(1411),
#  'make': np.int64(1265),
#  'wet': np.int64(2368),
#  'fine': np.int64(742),
#  'way': np.int64(2341),
#  'feel': np.int64(725),
#  'england': np.int64(650),
#  'dont': np.int64(599),
#  'miss': np.int64(1334),
#  'team': np.int64(2034),
#  'news': np.int64(1425),
#  'ur': np.int64(2247),
#  'national': np.int64(1408),
#  'eg': np.int64(632),
#  'try': np.int64(2181),
#  'wales': np.int64(2319),
#  'scotland': np.int64(1780),
#  'wq': np.int64(2438),
#  'seriously': np.int64(1806),
#  'ha': np.int64(919),
#  'pay': np.int64(1520),
#  'first': np.int64(746),
#  'da': np.int64(517),
#  'stock': np.int64(1952),
#  'comin': np.int64(443),
#  'aft': np.int64(48),
#  'finish': np.int64(744),
#  'lunch': np.int64(1250),
#  'str': np.int64(1960),
#  'lor': np.int64(1225),
#  'ard': np.int64(144),
#  'smth': np.int64(1885),
#  'alright': np.int64(86),
#  'meet': np.int64(1303),
#  'sooner': np.int64(1906),
#  'force': np.int64(768),
#  'eat': np.int64(627),
#  'slice': np.int64(1874),
#  'really': np.int64(1675),
#  'hungry': np.int64(1013),
#  'tho': np.int64(2083),
#  'suck': np.int64(1981),
#  'mark': np.int64(1278),
#  'worry': np.int64(2429),
#  'know': np.int64(1134),
#  'sick': np.int64(1844),
#  'turn': np.int64(2192),
#  'pizza': np.int64(1556),
#  'lol': np.int64(1217),
#  'always': np.int64(90),
#  'convince': np.int64(471),
#  'catch': np.int64(369),
#  'bus': np.int64(323),
#  'fry': np.int64(798),
#  'egg': np.int64(633),
#  'tea': np.int64(2032),
#  'mom': np.int64(1353),
#  'leave': np.int64(1163),
#  'dinner': np.int64(575),
#  'love': np.int64(1237),
#  'amp': np.int64(97),
#  'pack': np.int64(1504),
#  'car': np.int64(355),
#  'let': np.int64(1175),
#  'room': np.int64(1746),
#  'work': np.int64(2425),
#  'wait': np.int64(2316),
#  'clear': np.int64(420),
#  'sure': np.int64(2001),
#  'us': np.int64(2256),
#  'yeah': np.int64(2472),
#  'fall': np.int64(702),
#  'spoil': np.int64(1929),
#  'child': np.int64(402),
#  'till': np.int64(2106),
#  'cheer': np.int64(398),
#  'tell': np.int64(2042),
#  'anything': np.int64(119),
#  'fear': np.int64(721),
#  'quick': np.int64(1645),
#  'subscription': np.int64(1978),
#  'ringtone': np.int64(1733),
#  'uk': np.int64(2212),
#  'charge': np.int64(388),
#  'month': np.int64(1362),
#  'please': np.int64(1563),
#  'confirm': np.int64(458),
#  'yup': np.int64(2498),
#  'look': np.int64(1222),
#  'msg': np.int64(1384),
#  'xuhui': np.int64(2458),
#  'learn': np.int64(1161),
#  'nd': np.int64(1412),
#  'lesson': np.int64(1173),
#  'oops': np.int64(1481),
#  'roommate': np.int64(1747),
#  'do': np.int64(590),
#  'see': np.int64(1790),
#  'letter': np.int64(1176),
#  'decide': np.int64(542),
#  'hello': np.int64(963),
#  'saturday': np.int64(1767),
#  'texting': np.int64(2057),
#  'tomo': np.int64(2136),
#  'invite': np.int64(1066),
#  'pls': np.int64(1566),
#  'ahead': np.int64(57),
#  'weekend': np.int64(2354),
#  'abiola': np.int64(3),
#  'forget': np.int64(772),
#  'need': np.int64(1416),
#  'crave': np.int64(492),
#  'sweet': np.int64(2006),
#  'yummy': np.int64(2494),
#  'burn': np.int64(322),
#  'sms': np.int64(1884),
#  'nokia': np.int64(1437),
#  'camcorder': np.int64(346),
#  'delivery': np.int64(553),
#  'tomorrow': np.int64(2138),
#  'hope': np.int64(991),
#  'man': np.int64(1269),
#  'well': np.int64(2362),
#  'lt': np.int64(1245),
#  'gt': np.int64(907),
#  'inch': np.int64(1043),
#  'nigeria': np.int64(1430),
#  'fair': np.int64(701),
#  'hopefully': np.int64(992),
#  'tyler': np.int64(2207),
#  'could': np.int64(481),
#  'maybe': np.int64(1294),
#  'ask': np.int64(164),
#  'bite': np.int64(263),
#  'hospital': np.int64(995),
#  'keep': np.int64(1120),
#  'weak': np.int64(2344),
#  'saw': np.int64(1771),
#  'class': np.int64(418),
#  'gram': np.int64(893),
#  'usually': np.int64(2265),
#  'run': np.int64(1757),
#  'half': np.int64(927),
#  'almost': np.int64(82),
#  'whole': np.int64(2378),
#  'second': np.int64(1787),
#  'fyi': np.int64(814),
#  'ride': np.int64(1730),
#  'morning': np.int64(1369),
#  'crash': np.int64(491),
#  'place': np.int64(1557),
#  'wow': np.int64(2436),
#  'never': np.int64(1422),
#  'realize': np.int64(1674),
#  'embarassed': np.int64(642),
#  'since': np.int64(1853),
#  'best': np.int64(246),
#  'seem': np.int64(1791),
#  'happy': np.int64(940),
#  'sorry': np.int64(1909),
#  'give': np.int64(866),
#  'offer': np.int64(1462),
#  'ac': np.int64(9),
#  'new': np.int64(1423),
#  'red': np.int64(1687),
#  'play': np.int64(1560),
#  'ice': np.int64(1024),
#  'correct': np.int64(477),
#  'end': np.int64(645),
#  'yesterday': np.int64(2482),
#  'find': np.int64(741),
#  'url': np.int64(2253),
#  'congrats': np.int64(460),
#  'year': np.int64(2473),
#  'special': np.int64(1921),
#  'cinema': np.int64(414),
#  'pass': np.int64(1516),
#  'suprman': np.int64(1999),
#  'matrix': np.int64(1287),
#  'starwars': np.int64(1943),
#  'etc': np.int64(667),
#  'bx': np.int64(330),
#  'ip': np.int64(1069),
#  'pm': np.int64(1569),
#  'later': np.int64(1149),
#  'reach': np.int64(1668),
#  'series': np.int64(1804),
#  'pick': np.int64(1545),
#  'move': np.int64(1376),
#  'pain': np.int64(1507),
#  'kill': np.int64(1127),
#  'good': np.int64(876),
#  'girls': np.int64(863),
#  'situation': np.int64(1862),
#  'part': np.int64(1513),
#  'check': np.int64(397),
#  'iq': np.int64(1071),
#  'roommates': np.int64(1748),
#  'forever': np.int64(770),
#  'come': np.int64(441),
#  'double': np.int64(603),
#  'hair': np.int64(925),
#  'dresser': np.int64(608),
#  'wun': np.int64(2450),
#  'cut': np.int64(512),
#  'short': np.int64(1832),
#  'nice': np.int64(1428),
#  'advise': np.int64(40),
#  'follow': np.int64(763),
#  'recent': np.int64(1682),
#  'review': np.int64(1727),
#  'mob': np.int64(1344),
#  'award': np.int64(193),
#  'bonus': np.int64(283),
#  'song': np.int64(1901),
#  'valuable': np.int64(2273),
#  'frnds': np.int64(795),
#  'rply': np.int64(1751),
#  'complimentary': np.int64(451),
#  'trip': np.int64(2173),
#  'trav': np.int64(2169),
#  'aco': np.int64(19),
#  'dis': np.int64(580),
#  'ls': np.int64(1244),
#  'aj': np.int64(69),
#  'hear': np.int64(955),
#  'plane': np.int64(1559),
#  'wah': np.int64(2313),
#  'lucky': np.int64(1249),
#  'save': np.int64(1770),
#  'money': np.int64(1359),
#  'hee': np.int64(959),
#  'hi': np.int64(967),
#  'babe': np.int64(199),
#  'im': np.int64(1035),
#  'wanna': np.int64(2326),
#  'something': np.int64(1897),
#  'xx': np.int64(2459),
#  'machan': np.int64(1254),
#  'thats': np.int64(2068),
#  'cool': np.int64(473),
#  'gentleman': np.int64(847),
#  'dignity': np.int64(573),
#  'respect': np.int64(1718),
#  'people': np.int64(1526),
#  'much': np.int64(1393),
#  'shy': np.int64(1842),
#  'pa': np.int64(1503),
#  'job': np.int64(1099),
#  'ta': np.int64(2015),
#  'earn': np.int64(623),
#  'ah': np.int64(55),
#  'stop': np.int64(1955),
#  'urgnt': np.int64(2252),
#  'real': np.int64(1671),
#  'yo': np.int64(2488),
#  'ticket': np.int64(2102),
#  'one': np.int64(1475),
#  'start': np.int64(1942),
#  'bed': np.int64(232),
#  'coin': np.int64(433),
#  'gotta': np.int64(887),
#  'kano': np.int64(1116),
#  'il': np.int64(1033),
#  'download': np.int64(604),
#  'wen': np.int64(2364),
#  'stand': np.int64(1939),
#  'close': np.int64(424),
#  'another': np.int64(109),
#  'night': np.int64(1431),
#  'spend': np.int64(1926),
#  'late': np.int64(1148),
#  'afternoon': np.int64(49),
#  'mean': np.int64(1296),
#  'moro': np.int64(1370),
#  'include': np.int64(1045),
#  'sheet': np.int64(1822),
#  'smile': np.int64(1882),
#  'pleasure': np.int64(1564),
#  'trouble': np.int64(2174),
#  'pour': np.int64(1591),
#  'rain': np.int64(1654),
#  'sum': np.int64(1986),
#  'hurt': np.int64(1016),
#  'becoz': np.int64(231),
#  'someone': np.int64(1895),
#  'service': np.int64(1808),
#  'representative': np.int64(1713),
#  'guarantee': np.int64(909),
#  'havent': np.int64(948),
#  'plan': np.int64(1558),
#  'buy': np.int64(327),
#  'lido': np.int64(1180),
#  'show': np.int64(1838),
#  'collect': np.int64(436),
#  'simply': np.int64(1852),
#  'password': np.int64(1518),
#  'mix': np.int64(1337),
#  'verify': np.int64(2280),
#  'usher': np.int64(2263),
#  'fml': np.int64(762),
#  'movie': np.int64(1377),
#  'abt': np.int64(7),
#  'load': np.int64(1207),
#  'loan': np.int64(1208),
#  'wk': np.int64(2409),
#  'hols': np.int64(984),
#  'appointment': np.int64(133),
#  'four': np.int64(777),
#  'shower': np.int64(1839),
#  'cause': np.int64(370),
#  'prob': np.int64(1615),
#  'ham': np.int64(930),
#  'nothing': np.int64(1447),
#  'else': np.int64(638),
#  'okay': np.int64(1469),
#  'price': np.int64(1610),
#  'long': np.int64(1220),
#  'legal': np.int64(1166),
#  'ave': np.int64(188),
#  'drive': np.int64(610),
#  'test': np.int64(2052),
#  'yet': np.int64(2483),
#  'guess': np.int64(912),
#  'boston': np.int64(290),
#  'men': np.int64(1311),
#  'change': np.int64(385),
#  'nyc': np.int64(1458),
#  'cuz': np.int64(515),
#  'page': np.int64(1506),
#  'umma': np.int64(2215),
#  'life': np.int64(1182),
#  'vava': np.int64(2277),
#  'lot': np.int64(1228),
#  'dear': np.int64(537),
#  'wish': np.int64(2402),
#  'birthday': np.int64(260),
#  'truly': np.int64(2178),
#  'aight': np.int64(60),
#  'hit': np.int64(973),
#  'would': np.int64(2434),
#  'address': np.int64(32),
#  'consider': np.int64(464),
#  'computer': np.int64(452),
#  'old': np.int64(1472),
#  'better': np.int64(248),
#  'lie': np.int64(1181),
#  'busy': np.int64(325),
#  'research': np.int64(1716),
#  'cos': np.int64(478),
#  'things': np.int64(2077),
#  'scar': np.int64(1773),
#  'mah': np.int64(1260),
#  'loud': np.int64(1232),
#  'gent': np.int64(845),
#  'contact': np.int64(466),
#  'last': np.int64(1147),
#  'draw': np.int64(605),
#  'hrs': np.int64(1007),
#  'ppm': np.int64(1596),
#  'wa': np.int64(2312),
#  'sentence': np.int64(1801),
#  'anyway': np.int64(121),
#  'juz': np.int64(1113),
#  'tt': np.int64(2186),
#  'eatin': np.int64(628),
#  'weight': np.int64(2358),
#  'haha': np.int64(922),
#  'anythin': np.int64(118),
#  'happen': np.int64(936),
#  'enter': np.int64(654),
#  'cabin': np.int64(332),
#  'boss': np.int64(289),
#  'felt': np.int64(728),
#  'askd': np.int64(165),
#  'apartment': np.int64(125),
#  'specially': np.int64(1922),
#  'holiday': np.int64(982),
#  'flight': np.int64(756),
#  'inc': np.int64(1042),
#  'operator': np.int64(1483),
#  'min': np.int64(1323),
#  'goodo': np.int64(882),
#  'must': np.int64(1399),
#  'friday': np.int64(789),
#  'tortilla': np.int64(2151),
#  'hmm': np.int64(976),
#  'uncle': np.int64(2221),
#  'inform': np.int64(1051),
#  'school': np.int64(1777),
#  'directly': np.int64(578),
#  'food': np.int64(765),
#  'private': np.int64(1613),
#  'account': np.int64(16),
#  'statement': np.int64(1944),
#  'unredeemed': np.int64(2234),
#  'identifier': np.int64(1028),
#  'expire': np.int64(692),
#  'caller': np.int64(341),
#  'landline': np.int64(1143),
#  'box': np.int64(295),
#  'todays': np.int64(2128),
#  'voda': np.int64(2301),
#  'number': np.int64(1453),
#  'match': np.int64(1285),
#  'quote': np.int64(1650),
#  'standard': np.int64(1940),
#  'rat': np.int64(1661),
#  'app': np.int64(128),
#  'mu': np.int64(1392),
#  'yetunde': np.int64(2484),
#  'bother': np.int64(291),
#  'apologise': np.int64(127),
#  'girl': np.int64(861),
#  'del': np.int64(548),
#  'bak': np.int64(206),
#  'answer': np.int64(112),
#  'sunshine': np.int64(1991),
#  'quiz': np.int64(1649),
#  'top': np.int64(2148),
#  'sony': np.int64(1903),
#  'dvd': np.int64(620),
#  'player': np.int64(1561),
#  'country': np.int64(483),
#  'algarve': np.int64(78),
#  'ansr': np.int64(111),
#  'sp': np.int64(1917),
#  'tyrone': np.int64(2209),
#  'lay': np.int64(1154),
#  'dog': np.int64(595),
#  'locations': np.int64(1210),
#  'direct': np.int64(577),
#  'join': np.int64(1102),
#  'largest': np.int64(1146),
#  'bt': np.int64(313),
#  'txting': np.int64(2202),
#  'nt': np.int64(1449),
#  'ec': np.int64(629),
#  'haf': np.int64(921),
#  'yijue': np.int64(2486),
#  'befor': np.int64(235),
#  'activities': np.int64(24),
#  'msgs': np.int64(1387),
#  'chat': np.int64(392),
#  'hardcore': np.int64(942),
#  'age': np.int64(52),
#  'yr': np.int64(2492),
#  'lazy': np.int64(1155),
#  'type': np.int64(2208),
#  'lect': np.int64(1164),
#  'sir': np.int64(1857),
#  'mail': np.int64(1262),
#  'swt': np.int64(2011),
#  'tire': np.int64(2109),
#  'little': np.int64(1203),
#  'lovable': np.int64(1236),
#  'persons': np.int64(1534),
#  'coz': np.int64(487),
#  'occupy': np.int64(1461),
#  'biggest': np.int64(254),
#  'hearts': np.int64(957),
#  'gud': np.int64(910),
#  'ni': np.int64(1427),
#  'open': np.int64(1482),
#  'ya': np.int64(2465),
#  'dot': np.int64(602),
#  'whats': np.int64(2370),
#  'staff': np.int64(1937),
#  'sexy': np.int64(1814),
#  'female': np.int64(729),
#  'local': np.int64(1209),
#  'luv': np.int64(1251),
#  'netcollex': np.int64(1419),
#  'ltd': np.int64(1246),
#  'begin': np.int64(237),
#  'qatar': np.int64(1639),
#  'pray': np.int64(1600),
#  'hard': np.int64(941),
#  'delete': np.int64(550),
#  'birla': np.int64(258),
#  'soft': np.int64(1890),
#  'wine': np.int64(2397),
#  'flow': np.int64(759),
#  'thk': np.int64(2080),
#  'floor': np.int64(758),
#  'windows': np.int64(2396),
#  'shirt': np.int64(1826),
#  'sometimes': np.int64(1899),
#  'dream': np.int64(606),
#  'without': np.int64(2407),
#  'joy': np.int64(1106),
#  'tv': np.int64(2193),
#  'become': np.int64(230),
#  'house': np.int64(1001),
#  'interview': np.int64(1064),
#  'boy': np.int64(296),
#  'years': np.int64(2474),
#  'arrange': np.int64(155),
#  'safe': np.int64(1762),
#  'everyone': np.int64(674),
#  'parent': np.int64(1510),
#  'hand': np.int64(932),
#  'excite': np.int64(685),
#  'friend': np.int64(790),
#  'frnd': np.int64(794),
#  'order': np.int64(1491),
#  'content': np.int64(467),
#  'goto': np.int64(886),
#  'internet': np.int64(1063),
#  'menu': np.int64(1312),
#  'avoid': np.int64(190),
#  'wit': np.int64(2405),
#  'escape': np.int64(662),
#  'fancy': np.int64(705),
#  'completely': np.int64(450),
#  'form': np.int64(774),
#  'also': np.int64(88),
#  'utter': np.int64(2266),
#  'waste': np.int64(2333),
#  'bank': np.int64(210),
#  'hmmm': np.int64(977),
#  'hop': np.int64(990),
#  'muz': np.int64(1400),
#  'discuss': np.int64(583),
#  'liao': np.int64(1177),
#  'bloody': np.int64(275),
#  'hell': np.int64(961),
#  'cant': np.int64(353),
#  'believe': np.int64(241),
#  'mr': np.int64(1380),
#  'ill': np.int64(1034),
#  'spanish': np.int64(1919),
#  'bath': np.int64(217),
#  'carlos': np.int64(362),
#  'mall': np.int64(1268),
#  'stay': np.int64(1946),
#  'til': np.int64(2105),
#  'smoke': np.int64(1883),
#  'worth': np.int64(2432),
#  'doesnt': np.int64(594),
#  'log': np.int64(1213),
#  'maneesha': np.int64(1273),
#  'satisfy': np.int64(1766),
#  'experience': np.int64(691),
#  'toll': np.int64(2132),
#  'lift': np.int64(1185),
#  'especially': np.int64(664),
#  'approach': np.int64(135),
#  'study': np.int64(1969),
#  'anyways': np.int64(122),
#  'gr': np.int64(890),
#  'trust': np.int64(2179),
#  'guy': np.int64(915),
#  'bye': np.int64(331),
#  'towards': np.int64(2159),
#  'mummy': np.int64(1395),
#  'boytoy': np.int64(299),
#  'awesome': np.int64(195),
#  'minute': np.int64(1330),
#  'freephone': np.int64(784),
#  'xmas': np.int64(2457),
#  'radio': np.int64(1652),
#  'jus': np.int64(1112),
#  'bathe': np.int64(218),
#  'sis': np.int64(1858),
#  'unique': np.int64(2227),
#  'th': np.int64(2063),
#  'august': np.int64(180),
#  'touch': np.int64(2156),
#  'deal': np.int64(536),
#  'personal': np.int64(1532),
#  'finally': np.int64(740),
#  'complete': np.int64(449),
#  'course': np.int64(485),
#  'however': np.int64(1002),
#  'suggest': np.int64(1984),
#  'able': np.int64(5),
#  'every': np.int64(672),
#  'settle': np.int64(1811),
#  'wishin': np.int64(2403),
#  'mrng': np.int64(1381),
#  'hav': np.int64(947),
#  'story': np.int64(1959),
#  'hamster': np.int64(931),
#  'dead': np.int64(535),
#  'tmr': np.int64(2120),
#  'orchard': np.int64(1490),
#  'mrt': np.int64(1382),
#  'kate': np.int64(1118),
#  'buck': np.int64(315),
#  'darlin': np.int64(526),
#  'ive': np.int64(1080),
#  'college': np.int64(438),
#  'successfully': np.int64(1980),
#  'decimal': np.int64(543),
#  'balance': np.int64(207),
#  'rs': np.int64(1752),
#  'transaction': np.int64(2165),
#  'id': np.int64(1025),
#  'goodmorning': np.int64(878),
#  'sleep': np.int64(1873),
#  'ga': np.int64(815),
#  'dat': np.int64(529),
#  'oso': np.int64(1495),
#  'cannot': np.int64(352),
#  'oredi': np.int64(1492),
#  'straight': np.int64(1961),
#  'connection': np.int64(463),
#  'bill': np.int64(255),
#  'shoot': np.int64(1830),
#  'big': np.int64(252),
#  'ready': np.int64(1670),
#  'break': np.int64(302),
#  'semester': np.int64(1796),
#  'noe': np.int64(1436),
#  'leh': np.int64(1168),
#  'sound': np.int64(1913),
#  'head': np.int64(952),
#  'past': np.int64(1519),
#  'nights': np.int64(1432),
#  'easy': np.int64(626),
#  'sen': np.int64(1797),
#  'exam': np.int64(681),
#  'march': np.int64(1276),
#  'atm': np.int64(173),
#  'register': np.int64(1693),
#  'important': np.int64(1039),
#  'file': np.int64(736),
#  'system': np.int64(2014),
#  'repair': np.int64(1708),
#  'shop': np.int64(1831),
#  'romantic': np.int64(1744),
#  'nite': np.int64(1434),
#  'tc': np.int64(2029),
#  'biz': np.int64(264),
#  'optout': np.int64(1488),
#  'gbp': np.int64(836),
#  'mtmsg': np.int64(1390),
#  'appreciate': np.int64(134),
#  'partner': np.int64(1514),
#  'career': np.int64(359),
#  'star': np.int64(1941),
#  'sign': np.int64(1848),
#  'company': np.int64(447),
#  'po': np.int64(1570),
#  'bcoz': np.int64(225),
#  'teach': np.int64(2033),
#  'lessons': np.int64(1174),
#  'walk': np.int64(2320),
#  'cross': np.int64(497),
#  'road': np.int64(1737),
#  'side': np.int64(1845),
#  'street': np.int64(1963),
#  'battery': np.int64(219),
#  'die': np.int64(566),
#  'flirt': np.int64(757),
#  'sam': np.int64(1765),
#  'recd': np.int64(1679),
#  'pence': np.int64(1524),
#  'print': np.int64(1612),
#  'upstairs': np.int64(2245),
#  'closer': np.int64(425),
#  'wil': np.int64(2389),
#  'theory': np.int64(2072),
#  'argument': np.int64(149),
#  'lose': np.int64(1226),
#  'person': np.int64(1531),
#  'argue': np.int64(148),
#  'kick': np.int64(1124),
#  'secret': np.int64(1788),
#  'admirer': np.int64(33),
#  'reveal': np.int64(1726),
#  'tomarrow': np.int64(2134),
#  'laptop': np.int64(1144),
#  'case': np.int64(366),
#  'tel': np.int64(2041),
#  'avent': np.int64(189),
#  'although': np.int64(89),
#  'face': np.int64(697),
#  'fr': np.int64(778),
#  'thanx': np.int64(2067),
#  'everything': np.int64(675),
#  'website': np.int64(2348),
#  'slippers': np.int64(1876),
#  'kallis': np.int64(1115),
#  'bat': np.int64(216),
#  'innings': np.int64(1053),
#  'didnt': np.int64(565),
#  'goodnight': np.int64(879),
#  'fix': np.int64(750),
#  'wake': np.int64(2318),
#  'dearly': np.int64(539),
#  'congratulations': np.int64(461),
#  'cd': np.int64(373),
#  'vouchers': np.int64(2309),
#  'gift': np.int64(859),
#  'music': np.int64(1398),
#  'tncs': np.int64(2124),
#  'ldew': np.int64(1156),
#  'ppmx': np.int64(1597),
#  'ranjith': np.int64(1660),
#  'cal': np.int64(335),
#  'hold': np.int64(980),
#  'bcums': np.int64(226),
#  'angry': np.int64(102),
#  'wid': np.int64(2383),
#  'dnt': np.int64(589),
#  'childish': np.int64(403),
#  'true': np.int64(2176),
#  'deep': np.int64(545),
#  'affection': np.int64(46),
#  'care': np.int64(358),
#  'kettoda': np.int64(1122),
#  'manda': np.int64(1272),
#  'up': np.int64(2239),
#  'ship': np.int64(1825),
#  'wks': np.int64(2414),
#  'lemme': np.int64(1170),
#  'expect': np.int64(689),
#  'headin': np.int64(954),
#  'mmm': np.int64(1339),
#  'lover': np.int64(1239),
#  'video': np.int64(2285),
#  'handset': np.int64(934),
#  'anytime': np.int64(120),
#  'mins': np.int64(1329),
#  'unlimited': np.int64(2232),
#  'park': np.int64(1512),
#  'mini': np.int64(1326),
#  'disturb': np.int64(587),
#  'ring': np.int64(1732),
#  'horny': np.int64(993),
#  'naked': np.int64(1403),
#  'hot': np.int64(997),
#  'unsubscribe': np.int64(2237),
#  'dint': np.int64(576),
#  'wana': np.int64(2325),
#  'club': np.int64(426),
#  'choose': np.int64(410),
#  'wt': np.int64(2446),
#  'flash': np.int64(754),
#  'jealous': np.int64(1094),
#  'single': np.int64(1855),
#  'chart': np.int64(390),
#  'quality': np.int64(1642),
#  'sort': np.int64(1910),
#  'sunny': np.int64(1990),
#  'ray': np.int64(1664),
#  'blue': np.int64(277),
#  'bay': np.int64(220),
#  'hmv': np.int64(978),
#  'genuine': np.int64(849),
#  'percent': np.int64(1528),
#  'might': np.int64(1320),
#  'bf': np.int64(250),
#  'full': np.int64(803),
#  'swing': np.int64(2009),
#  'tool': np.int64(2144),
#  'far': np.int64(708),
#  'okie': np.int64(1471),
#  'usual': np.int64(2264),
#  'anybody': np.int64(115),
#  'throw': np.int64(2092),
#  'baby': np.int64(201),
#  'hour': np.int64(999),
#  'fone': np.int64(764),
#  'ge': np.int64(838),
#  'shall': np.int64(1818),
#  'tonite': np.int64(2142),
#  'sense': np.int64(1800),
#  'gautham': np.int64(832),
#  'stupid': np.int64(1971),
#  'cam': np.int64(345),
#  'buzy': np.int64(328),
#  'accidentally': np.int64(14),
#  'phone': np.int64(1541),
#  'upgrade': np.int64(2242),
#  'sim': np.int64(1850),
#  'card': np.int64(356),
#  'loyalty': np.int64(1242),
#  'unless': np.int64(2231),
#  'tease': np.int64(2036),
#  'plz': np.int64(1568),
#  'rise': np.int64(1735),
#  'grave': np.int64(896),
#  'bslvyl': np.int64(311),
#  'coffee': np.int64(432),
#  'somebody': np.int64(1894),
#  'high': np.int64(969),
#  'shit': np.int64(1827),
#  'shock': np.int64(1829),
#  'scary': np.int64(1774),
#  'imagine': np.int64(1036),
#  'def': np.int64(546),
#  'somewhere': np.int64(1900),
#  'meal': np.int64(1295),
#  'actor': np.int64(25),
#  'hide': np.int64(968),
#  'book': np.int64(285),
#  'friendship': np.int64(792),
#  'hang': np.int64(935),
#  'thread': np.int64(2088),
#  'themob': np.int64(2071),
#  'newest': np.int64(1424),
#  'selection': np.int64(1793),
#  'game': np.int64(820),
#  'tone': np.int64(2139),
#  'gossip': np.int64(885),
#  'babes': np.int64(200),
#  'sport': np.int64(1931),
#  'fit': np.int64(748),
#  'funky': np.int64(809),
#  'garage': np.int64(825),
#  'key': np.int64(1123),
#  'accept': np.int64(11),
#  'sister': np.int64(1859),
#  'clos': np.int64(423),
#  'lvblefrnd': np.int64(1253),
#  'jstfrnd': np.int64(1108),
#  'cutefrnd': np.int64(514),
#  'lifpartnr': np.int64(1184),
#  'belovd': np.int64(244),
#  'swtheart': np.int64(2012),
#  'bstfrnd': np.int64(312),
#  'enemy': np.int64(646),
#  'smart': np.int64(1880),
#  'weekly': np.int64(2355),
#  'cs': np.int64(501),
#  'uz': np.int64(2267),
#  'definitely': np.int64(547),
#  'normal': np.int64(1444),
#  'rest': np.int64(1722),
#  'wot': np.int64(2433),
#  'advance': np.int64(37),
#  'pongal': np.int64(1580),
#  'kb': np.int64(1119),
#  'power': np.int64(1592),
#  'yoga': np.int64(2489),
#  'dunno': np.int64(619),
#  'anot': np.int64(108),
#  'dude': np.int64(616),
#  'afraid': np.int64(47),
#  'december': np.int64(541),
#  'mths': np.int64(1389),
#  'cake': np.int64(334),
#  'merry': np.int64(1313),
#  'christmas': np.int64(411),
#  'kiss': np.int64(1132),
#  'cud': np.int64(503),
#  ...}

# %%
# bag of words but with ngrams - UNIGRAM AND BIGRAM
# create new bag of words with lemmatizer
# lemma_cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(1, 2))
lemma_cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(2, 2)) # ignoring unigram
X = lemma_cv.fit_transform(lemma_corpus).toarray()
lemma_cv.vocabulary_
# Out:
# {'ok lar': np.int64(1425),
#  'free entry': np.int64(612),
#  'entry wkly': np.int64(539),
#  'wkly comp': np.int64(2417),
#  'cup final': np.int64(399),
#  'tkts st': np.int64(2119),
#  'std txt': np.int64(1957),
#  'txt rate': np.int64(2196),
#  'rate apply': np.int64(1702),
#  'already say': np.int64(27),
#  'think go': np.int64(2077),
#  'freemsg hey': np.int64(633),
#  'like fun': np.int64(1086),
#  'per request': np.int64(1479),
#  'request melle': np.int64(1757),
#  'melle melle': np.int64(1225),
#  'melle oru': np.int64(1226),
#  'oru minnaminunginte': np.int64(1457),
#  'minnaminunginte nurungu': np.int64(1248),
#  'nurungu vettam': np.int64(1404),
#  'vettam set': np.int64(2285),
#  'set callertune': np.int64(1851),
#  'callertune callers': np.int64(234),
#  'callers press': np.int64(233),
#  'press copy': np.int64(1659),
#  'copy friends': np.int64(368),
#  'friends callertune': np.int64(639),
#  'winner value': np.int64(2405),
#  'value network': np.int64(2283),
#  'network customer': np.int64(1354),
#  'prize reward': np.int64(1680),
#  'claim call': np.int64(284),
#  'call claim': np.int64(189),
#  'claim code': np.int64(285),
#  'valid hours': np.int64(2280),
#  'entitle update': np.int64(536),
#  'update latest': np.int64(2220),
#  'latest colour': np.int64(1055),
#  'free call': np.int64(607),
#  'call mobile': np.int64(210),
#  'mobile update': np.int64(1282),
#  'update co': np.int64(2219),
#  'co free': np.int64(299),
#  'want talk': np.int64(2340),
#  'chance win': np.int64(265),
#  'win cash': np.int64(2392),
#  'pound txt': np.int64(1639),
#  'reply hl': np.int64(1745),
#  'hl info': np.int64(913),
#  'week free': np.int64(2362),
#  'prize jackpot': np.int64(1677),
#  'txt word': np.int64(2201),
#  'pobox ldnw': np.int64(1601),
#  'dont miss': np.int64(494),
#  'txt ur': np.int64(2200),
#  'go try': np.int64(776),
#  'ha ha': np.int64(857),
#  'finish lunch': np.int64(588),
#  'ard smth': np.int64(61),
#  'finish ur': np.int64(589),
#  'get worry': np.int64(719),
#  'let know': np.int64(1076),
#  'feel like': np.int64(569),
#  'yeah get': np.int64(2469),
#  'tell anything': np.int64(2029),
#  'mobile charge': np.int64(1273),
#  'charge month': np.int64(268),
#  'reply yes': np.int64(1754),
#  'yup ok': np.int64(2496),
#  'ok go': np.int64(1422),
#  'go home': np.int64(747),
#  'anything lor': np.int64(52),
#  'pls go': np.int64(1575),
#  'great weekend': np.int64(821),
#  'forget tell': np.int64(601),
#  'want need': np.int64(2332),
#  'need crave': np.int64(1342),
#  'try call': np.int64(2173),
#  'call reply': np.int64(222),
#  'reply sms': np.int64(1750),
#  'free nokia': np.int64(620),
#  'nokia mobile': np.int64(1387),
#  'mobile free': np.int64(1278),
#  'free camcorder': np.int64(608),
#  'please call': np.int64(1551),
#  'call delivery': np.int64(195),
#  'delivery tomorrow': np.int64(463),
#  'hope like': np.int64(943),
#  'lt gt': np.int64(1161),
#  'gt inch': np.int64(829),
#  'call message': np.int64(207),
#  'message miss': np.int64(1233),
#  'miss call': np.int64(1262),
#  'anything go': np.int64(51),
#  'want go': np.int64(2328),
#  'go hospital': np.int64(748),
#  'first time': np.int64(593),
#  'run like': np.int64(1776),
#  'like lt': np.int64(1091),
#  'early tomorrow': np.int64(517),
#  'tomorrow morning': np.int64(2157),
#  'sms ac': np.int64(1894),
#  'reply end': np.int64(1744),
#  'lt url': np.int64(1163),
#  'url gt': np.int64(2270),
#  'congrats year': np.int64(350),
#  'year special': np.int64(2475),
#  'special cinema': np.int64(1936),
#  'cinema pass': np.int64(282),
#  'pass call': np.int64(1466),
#  'call suprman': np.int64(225),
#  'suprman matrix': np.int64(2000),
#  'matrix starwars': np.int64(1206),
#  'starwars etc': np.int64(1954),
#  'etc free': np.int64(540),
#  'free bx': np.int64(606),
#  'bx ip': np.int64(181),
#  'ip pm': np.int64(987),
#  'pm dont': np.int64(1595),
#  'sorry call': np.int64(1913),
#  'call later': np.int64(206),
#  'later meet': np.int64(1052),
#  'way home': np.int64(2355),
#  'home even': np.int64(928),
#  'take forever': np.int64(2013),
#  'ok come': np.int64(1421),
#  'hair dresser': np.int64(861),
#  'cut short': np.int64(408),
#  'value customer': np.int64(2282),
#  'customer please': np.int64(406),
#  'please advise': np.int64(1549),
#  'advise follow': np.int64(17),
#  'follow recent': np.int64(597),
#  'recent review': np.int64(1732),
#  'review mob': np.int64(1763),
#  'mob award': np.int64(1268),
#  'award bonus': np.int64(83),
#  'bonus prize': np.int64(146),
#  'prize call': np.int64(1671),
#  'today song': np.int64(2141),
#  'send ur': np.int64(1841),
#  'urgent ur': np.int64(2268),
#  'ur award': np.int64(2223),
#  'month end': np.int64(1288),
#  'hi babe': np.int64(903),
#  'im home': np.int64(966),
#  'call free': np.int64(196),
#  'thats cool': np.int64(2068),
#  'gentleman treat': np.int64(664),
#  'treat dignity': np.int64(2170),
#  'dignity respect': np.int64(473),
#  'hi hi': np.int64(908),
#  'place man': np.int64(1530),
#  'start send': np.int64(1952),
#  'pain come': np.int64(1460),
#  'come back': np.int64(322),
#  'still tonight': np.int64(1966),
#  'wen ur': np.int64(2378),
#  'pleasure smile': np.int64(1565),
#  'pour like': np.int64(1640),
#  'like rain': np.int64(1094),
#  'still love': np.int64(1963),
#  'love see': np.int64(1149),
#  'see smile': np.int64(1813),
#  'call customer': np.int64(193),
#  'customer service': np.int64(407),
#  'service representative': np.int64(1849),
#  'representative pm': np.int64(1756),
#  'pm guarantee': np.int64(1597),
#  'guarantee cash': np.int64(845),
#  'cash prize': np.int64(258),
#  'finish work': np.int64(590),
#  'free ringtone': np.int64(623),
#  'wat abt': np.int64(2344),
#  'need get': np.int64(1344),
#  'get home': np.int64(685),
#  'love lot': np.int64(1146),
#  'get cash': np.int64(673),
#  'always one': np.int64(29),
#  'dont worry': np.int64(500),
#  'go dinner': np.int64(743),
#  'dun like': np.int64(511),
#  'try contact': np.int64(2174),
#  'contact last': np.int64(357),
#  'last weekend': np.int64(1049),
#  'weekend draw': np.int64(2368),
#  'draw show': np.int64(504),
#  'show prize': np.int64(1861),
#  'prize guarantee': np.int64(1676),
#  'guarantee call': np.int64(844),
#  'code valid': np.int64(303),
#  'valid hrs': np.int64(2281),
#  'hrs ppm': np.int64(953),
#  'enter cabin': np.int64(532),
#  'cabin pa': np.int64(182),
#  'pa say': np.int64(1459),
#  'say happy': np.int64(1790),
#  'happy day': np.int64(874),
#  'day boss': np.int64(424),
#  'boss felt': np.int64(158),
#  'felt special': np.int64(572),
#  'special askd': np.int64(1934),
#  'askd lunch': np.int64(76),
#  'lunch lunch': np.int64(1167),
#  'lunch invite': np.int64(1166),
#  'invite apartment': np.int64(983),
#  'apartment go': np.int64(58),
#  'winner specially': np.int64(2404),
#  'specially select': np.int64(1942),
#  'select receive': np.int64(1820),
#  'holiday flight': np.int64(923),
#  'flight inc': np.int64(596),
#  'inc speak': np.int64(974),
#  'speak live': np.int64(1931),
#  'live operator': np.int64(1106),
#  'operator claim': np.int64(1445),
#  'buy food': np.int64(179),
#  'private account': np.int64(1669),
#  'account statement': np.int64(12),
#  'statement show': np.int64(1955),
#  'show unredeemed': np.int64(1863),
#  'unredeemed bonus': np.int64(2216),
#  'bonus point': np.int64(145),
#  'point claim': np.int64(1613),
#  'call identifier': np.int64(202),
#  'identifier code': np.int64(960),
#  'code expire': np.int64(301),
#  'urgent mobile': np.int64(2264),
#  'mobile award': np.int64(1272),
#  'bonus caller': np.int64(144),
#  'caller prize': np.int64(232),
#  'prize final': np.int64(1675),
#  'contact call': np.int64(353),
#  'call landline': np.int64(205),
#  'todays voda': np.int64(2152),
#  'voda number': np.int64(2293),
#  'number end': np.int64(1400),
#  'end select': np.int64(529),
#  'receive award': np.int64(1729),
#  'award match': np.int64(88),
#  'match please': np.int64(1205),
#  'call quote': np.int64(220),
#  'quote claim': np.int64(1697),
#  'code standard': np.int64(302),
#  'standard rat': np.int64(1949),
#  'rat app': np.int64(1700),
#  'today do': np.int64(2131),
#  'wat time': np.int64(2347),
#  'time finish': np.int64(2090),
#  'send text': np.int64(1840),
#  'hope well': np.int64(947),
#  'long time': np.int64(1117),
#  'time give': np.int64(2092),
#  'give call': np.int64(728),
#  'dear call': np.int64(440),
#  'answer question': np.int64(47),
#  'sunshine quiz': np.int64(1998),
#  'quiz wkly': np.int64(1696),
#  'wkly win': np.int64(2419),
#  'win top': np.int64(2401),
#  'top sony': np.int64(2169),
#  'sony dvd': np.int64(1911),
#  'dvd player': np.int64(516),
#  'player know': np.int64(1547),
#  'know country': np.int64(1016),
#  'txt ansr': np.int64(2185),
#  'ansr sp': np.int64(45),
#  'sp tyrone': np.int64(1930),
#  'want get': np.int64(2327),
#  'get lay': np.int64(688),
#  'tonight want': np.int64(2168),
#  'want real': np.int64(2335),
#  'real dog': np.int64(1715),
#  'dog locations': np.int64(485),
#  'locations send': np.int64(1108),
#  'send direct': np.int64(1824),
#  'direct ur': np.int64(475),
#  'ur mob': np.int64(2244),
#  'join uk': np.int64(996),
#  'uk largest': np.int64(2208),
#  'largest dog': np.int64(1042),
#  'dog network': np.int64(486),
#  'check room': np.int64(276),
#  'room befor': np.int64(1770),
#  'befor activities': np.int64(109),
#  'go get': np.int64(744),
#  'get nothing': np.int64(696),
#  'text way': np.int64(2055),
#  'sir wait': np.int64(1871),
#  'gud ni': np.int64(851),
#  'yes see': np.int64(2483),
#  'see ya': np.int64(1817),
#  'netcollex ltd': np.int64(1353),
#  'per msg': np.int64(1477),
#  'msg reply': np.int64(1308),
#  'reply stop': np.int64(1751),
#  'stop end': np.int64(1973),
#  'get job': np.int64(686),
#  'birla soft': np.int64(114),
#  'yup thk': np.int64(2497),
#  'need go': np.int64(1345),
#  'leave house': np.int64(1067),
#  'hello love': np.int64(893),
#  'good boy': np.int64(792),
#  'think miss': np.int64(2080),
#  'new years': np.int64(1371),
#  'receive cash': np.int64(1730),
#  'cash holiday': np.int64(257),
#  'miss already': np.int64(1260),
#  'new job': np.int64(1360),
#  'make happy': np.int64(1181),
#  'invite friend': np.int64(984),
#  'friend reply': np.int64(637),
#  'see www': np.int64(1816),
#  'www sms': np.int64(2455),
#  'stop send': np.int64(1977),
#  'send stop': np.int64(1838),
#  'stop frnd': np.int64(1975),
#  'ur mobile': np.int64(2245),
#  'urgent try': np.int64(2267),
#  'sure get': np.int64(2001),
#  'get time': np.int64(711),
#  'ya go': np.int64(2466),
#  'time come': np.int64(2089),
#  'come later': np.int64(327),
#  'finish bath': np.int64(587),
#  'know get': np.int64(1018),
#  'get money': np.int64(693),
#  'still go': np.int64(1960),
#  'friends stay': np.int64(642),
#  'back til': np.int64(98),
#  'gt worth': np.int64(840),
#  'hi speak': np.int64(911),
#  'speak maneesha': np.int64(1932),
#  'maneesha like': np.int64(1192),
#  'like know': np.int64(1090),
#  'know satisfy': np.int64(1025),
#  'satisfy experience': np.int64(1780),
#  'experience reply': np.int64(553),
#  'reply toll': np.int64(1752),
#  'toll free': np.int64(2154),
#  'free yes': np.int64(632),
#  'end month': np.int64(528),
#  'get back': np.int64(669),
#  'boytoy miss': np.int64(168),
#  'haha awesome': np.int64(858),
#  'representative freephone': np.int64(1755),
#  'freephone pm': np.int64(634),
#  'time get': np.int64(2091),
#  'reach home': np.int64(1709),
#  'home go': np.int64(930),
#  'go bathe': np.int64(737),
#  'co uk': np.int64(300),
#  'keep touch': np.int64(1007),
#  'great week': np.int64(820),
#  'complete course': np.int64(344),
#  'gr day': np.int64(810),
#  'gud mrng': np.int64(850),
#  'mrng dear': np.int64(1300),
#  'dear hav': np.int64(442),
#  'hav nice': np.int64(879),
#  'nice day': np.int64(1376),
#  'get persons': np.int64(700),
#  'persons story': np.int64(1486),
#  'hey tmr': np.int64(901),
#  'tmr meet': np.int64(2123),
#  'hi kate': np.int64(910),
#  'see tomorrow': np.int64(1815),
#  'txt back': np.int64(2186),
#  'send lt': np.int64(1833),
#  'gt buck': np.int64(824),
#  'love kate': np.int64(1143),
#  'lt decimal': np.int64(1160),
#  'decimal gt': np.int64(452),
#  'prepay account': np.int64(1657),
#  'rs lt': np.int64(1774),
#  'say like': np.int64(1793),
#  'like dat': np.int64(1085),
#  'please give': np.int64(1557),
#  'give us': np.int64(731),
#  'today lt': np.int64(2135),
#  'get ready': np.int64(703),
#  'hope great': np.int64(942),
#  'sleep well': np.int64(1884),
#  'yeah think': np.int64(2473),
#  'ok prob': np.int64(1429),
#  'take ur': np.int64(2021),
#  'ur time': np.int64(2255),
#  'bite lor': np.int64(120),
#  'new mobiles': np.int64(1363),
#  'mobiles must': np.int64(1284),
#  'must go': np.int64(1326),
#  'go txt': np.int64(777),
#  'txt nokia': np.int64(2194),
#  'nokia collect': np.int64(1382),
#  'collect today': np.int64(308),
#  'today www': np.int64(2149),
#  'www tc': np.int64(2456),
#  'tc biz': np.int64(2025),
#  'biz optout': np.int64(123),
#  'optout gbp': np.int64(1450),
#  'gbp mtmsg': np.int64(659),
#  'would really': np.int64(2443),
#  'really appreciate': np.int64(1719),
#  'good morning': np.int64(801),
#  'work place': np.int64(2432),
#  'text meet': np.int64(2051),
#  'name age': np.int64(1328),
#  'msg recd': np.int64(1307),
#  'bus stop': np.int64(177),
#  'new theory': np.int64(1366),
#  'theory argument': np.int64(2071),
#  'argument win': np.int64(63),
#  'win situation': np.int64(2398),
#  'situation lose': np.int64(1875),
#  'lose person': np.int64(1130),
#  'person dont': np.int64(1482),
#  'dont argue': np.int64(487),
#  'argue ur': np.int64(62),
#  'ur friends': np.int64(2230),
#  'friends kick': np.int64(641),
#  'kick amp': np.int64(1011),
#  'amp say': np.int64(36),
#  'say always': np.int64(1784),
#  'always correct': np.int64(28),
#  'secret admirer': np.int64(1804),
#  'admirer look': np.int64(16),
#  'look make': np.int64(1120),
#  'make contact': np.int64(1176),
#  'contact find': np.int64(356),
#  'find reveal': np.int64(582),
#  'reveal think': np.int64(1762),
#  'think ur': np.int64(2083),
#  'ur special': np.int64(2253),
#  'special call': np.int64(1935),
#  'tell dat': np.int64(2032),
#  'ask call': np.int64(70),
#  'oh ok': np.int64(1418),
#  'good night': np.int64(802),
#  'congratulations ur': np.int64(352),
#  'award cd': np.int64(85),
#  'cd vouchers': np.int64(263),
#  'vouchers gift': np.int64(2303),
#  'gift guarantee': np.int64(721),
#  'guarantee free': np.int64(846),
#  'wkly draw': np.int64(2418),
#  'draw txt': np.int64(506),
#  'txt music': np.int64(2193),
#  'music tncs': np.int64(1325),
#  'tncs www': np.int64(2125),
#  'www ldew': np.int64(2452),
#  'ldew com': np.int64(1062),
#  'com win': np.int64(318),
#  'win ppmx': np.int64(2397),
#  'ppmx age': np.int64(1650),
#  'deeraj deepak': np.int64(456),
#  'deepak min': np.int64(455),
#  'ur lovable': np.int64(2239),
#  'lovable bcums': np.int64(1136),
#  'bcums angry': np.int64(105),
#  'angry wid': np.int64(42),
#  'wid dnt': np.int64(2384),
#  'dnt take': np.int64(484),
#  'take seriously': np.int64(2019),
#  'seriously coz': np.int64(1844),
#  'coz angry': np.int64(382),
#  'angry childish': np.int64(41),
#  'childish true': np.int64(277),
#  'true way': np.int64(2171),
#  'way show': np.int64(2357),
#  'show deep': np.int64(1860),
#  'deep affection': np.int64(454),
#  'affection care': np.int64(18),
#  'care luv': np.int64(249),
#  'luv kettoda': np.int64(1169),
#  'kettoda manda': np.int64(1010),
#  'manda nice': np.int64(1191),
#  'day da': np.int64(425),
#  'week get': np.int64(2363),
#  'get stuff': np.int64(706),
#  'lemme know': np.int64(1072),
#  'contact reply': np.int64(360),
#  'reply offer': np.int64(1747),
#  'offer video': np.int64(1410),
#  'video handset': np.int64(2288),
#  'handset anytime': np.int64(869),
#  'anytime network': np.int64(55),
#  'network mins': np.int64(1355),
#  'mins unlimited': np.int64(1254),
#  'unlimited text': np.int64(2215),
#  'text camcorder': np.int64(2047),
#  'camcorder reply': np.int64(235),
#  'reply call': np.int64(1741),
#  'come today': np.int64(338),
#  'today think': np.int64(2146),
#  'anyway go': np.int64(56),
#  'go shop': np.int64(769),
#  'cos sis': np.int64(372),
#  'dun disturb': np.int64(509),
#  'disturb liao': np.int64(481),
#  'ring ur': np.int64(1765),
#  'text stop': np.int64(2053),
#  'try get': np.int64(2176),
#  'get hold': np.int64(684),
#  'stop txt': np.int64(1981),
#  'po box': np.int64(1599),
#  'message free': np.int64(1231),
#  'night end': np.int64(1379),
#  'end another': np.int64(527),
#  'another day': np.int64(43),
#  'day morning': np.int64(431),
#  'morning come': np.int64(1293),
#  'come special': np.int64(336),
#  'special way': np.int64(1941),
#  'way may': np.int64(2356),
#  'may smile': np.int64(1211),
#  'smile like': np.int64(1887),
#  'like sunny': np.int64(1097),
#  'sunny ray': np.int64(1997),
#  'ray leave': np.int64(1705),
#  'leave worry': np.int64(1070),
#  'worry blue': np.int64(2439),
#  'blue blue': np.int64(137),
#  'blue bay': np.int64(136),
#  'hmv bonus': np.int64(915),
#  'bonus special': np.int64(147),
#  'special pound': np.int64(1939),
#  'pound genuine': np.int64(1635),
#  'genuine hmv': np.int64(666),
#  'hmv vouchers': np.int64(917),
#  'vouchers answer': np.int64(2300),
#  'answer easy': np.int64(46),
#  'easy question': np.int64(520),
#  'question play': np.int64(1694),
#  'play send': np.int64(1545),
#  'send hmv': np.int64(1830),
#  'hmv info': np.int64(916),
#  'info www': np.int64(978),
#  'www percent': np.int64(2453),
#  'percent real': np.int64(1481),
#  'real com': np.int64(1714),
#  'well take': np.int64(2376),
#  'see bite': np.int64(1807),
#  'get call': np.int64(671),
#  'last night': np.int64(1044),
#  'might come': np.int64(1242),
#  'hi baby': np.int64(904),
#  'baby im': np.int64(95),
#  'lot love': np.int64(1134),
#  'love life': np.int64(1145),
#  'life love': np.int64(1081),
#  'much buzy': np.int64(1315),
#  'mobile customer': np.int64(1276),
#  'customer may': np.int64(404),
#  'may claim': np.int64(1210),
#  'claim free': np.int64(287),
#  'free camera': np.int64(609),
#  'camera phone': np.int64(239),
#  'phone upgrade': np.int64(1499),
#  'sim card': np.int64(1867),
#  'loyalty call': np.int64(1157),
#  'call offer': np.int64(216),
#  'offer end': np.int64(1406),
#  'make cry': np.int64(1177),
#  'plz keep': np.int64(1589),
#  'keep one': np.int64(1004),
#  'cant pick': np.int64(243),
#  'pick phone': np.int64(1512),
#  'phone right': np.int64(1498),
#  'right pls': np.int64(1764),
#  'pls send': np.int64(1582),
#  'send message': np.int64(1835),
#  'time week': np.int64(2111),
#  'last time': np.int64(1047),
#  'today accept': np.int64(2128),
#  'accept day': np.int64(9),
#  'day accept': np.int64(423),
#  'accept brother': np.int64(8),
#  'brother sister': np.int64(172),
#  'sister lover': np.int64(1873),
#  'lover dear': np.int64(1156),
#  'dear best': np.int64(439),
#  'best clos': np.int64(111),
#  'clos lvblefrnd': np.int64(295),
#  'lvblefrnd jstfrnd': np.int64(1170),
#  'jstfrnd cutefrnd': np.int64(999),
#  'cutefrnd lifpartnr': np.int64(410),
#  'lifpartnr belovd': np.int64(1082),
#  'belovd swtheart': np.int64(110),
#  'swtheart bstfrnd': np.int64(2011),
#  'bstfrnd rply': np.int64(173),
#  'rply mean': np.int64(1773),
#  'mean enemy': np.int64(1212),
#  'gbp week': np.int64(661),
#  'hope find': np.int64(939),
#  'make day': np.int64(1178),
#  'great day': np.int64(814),
#  'power yoga': np.int64(1643),
#  'december mobile': np.int64(448),
#  'mobile mths': np.int64(1279),
#  'mths entitle': np.int64(1312),
#  'colour camera': np.int64(312),
#  'camera mobile': np.int64(238),
#  'merry christmas': np.int64(1228),
#  'babe love': np.int64(93),
#  'love ya': np.int64(1154),
#  'go watch': np.int64(779),
#  'would great': np.int64(2441),
#  'get touch': np.int64(712),
#  'good week': np.int64(806),
#  'well know': np.int64(2375),
#  'cool text': np.int64(367),
#  'could get': np.int64(377),
#  'call germany': np.int64(199),
#  'per minute': np.int64(1476),
#  'prepayment direct': np.int64(1658),
#  'phone number': np.int64(1496),
#  'please contact': np.int64(1553),
#  'valentines day': np.int64(2279),
#  'send go': np.int64(1829),
#  'go msg': np.int64(758),
#  'msg rcvd': np.int64(1306),
#  'sleep surf': np.int64(1883),
#  'thanx lot': np.int64(2067),
#  'practice go': np.int64(1652),
#  'ur mail': np.int64(2242),
#  'com txt': np.int64(317),
#  'really miss': np.int64(1722),
#  'great month': np.int64(815),
#  'today sorry': np.int64(2142),
#  'plz plz': np.int64(1591),
#  'plz slap': np.int64(1592),
#  'ur fault': np.int64(2228),
#  'try figure': np.int64(2175),
#  'gt ish': np.int64(830),
#  'insha allah': np.int64(981),
#  'ur cash': np.int64(2224),
#  'cash balance': np.int64(255),
#  'balance currently': np.int64(101),
#  'currently pound': np.int64(400),
#  'pound maximize': np.int64(1636),
#  'maximize ur': np.int64(1209),
#  'cash send': np.int64(259),
#  'msg cc': np.int64(1302),
#  'cc hg': np.int64(260),
#  'hg suite': np.int64(902),
#  'suite land': np.int64(1992),
#  'land row': np.int64(1036),
#  'row hl': np.int64(1771),
#  'work even': np.int64(2430),
#  'every day': np.int64(546),
#  'get st': np.int64(705),
#  'keep post': np.int64(1005),
#  'new year': np.int64(1370),
#  'look forward': np.int64(1118),
#  'good afternoon': np.int64(791),
#  'think love': np.int64(2079),
#  'take care': np.int64(2012),
#  'latest motorola': np.int64(1056),
#  'motorola sonyericsson': np.int64(1298),
#  'sonyericsson nokia': np.int64(1912),
#  'nokia free': np.int64(1384),
#  'free bluetooth': np.int64(605),
#  'double mins': np.int64(501),
#  'mins txt': np.int64(1252),
#  'call mobileupd': np.int64(212),
#  'mobileupd call': np.int64(1286),
#  'call optout': np.int64(217),
#  'message reply': np.int64(1236),
#  'hello boytoy': np.int64(890),
#  'geeee miss': np.int64(663),
#  'next lt': np.int64(1374),
#  'gt min': np.int64(833),
#  'pls tell': np.int64(1584),
#  'thank ringtone': np.int64(2066),
#  'ringtone order': np.int64(1768),
#  'order reference': np.int64(1455),
#  'per week': np.int64(1480),
#  'say happen': np.int64(1789),
#  'dont mistake': np.int64(495),
#  'yeah sure': np.int64(2472),
#  'couple minutes': np.int64(380),
#  'mins txts': np.int64(1253),
#  'bluetooth orange': np.int64(140),
#  'nokia motorola': np.int64(1388),
#  'phone call': np.int64(1489),
#  'customer place': np.int64(405),
#  'place call': np.int64(1526),
#  'dont like': np.int64(492),
#  'mths half': np.int64(1313),
#  'half price': np.int64(864),
#  'price orange': np.int64(1666),
#  'orange line': np.int64(1452),
#  'line rental': np.int64(1100),
#  'rental latest': np.int64(1739),
#  'latest camera': np.int64(1054),
#  'phone free': np.int64(1492),
#  'free phone': np.int64(621),
#  'phone mths': np.int64(1495),
#  'mths call': np.int64(1311),
#  'call mobilesdirect': np.int64(211),
#  'mobilesdirect free': np.int64(1285),
#  'free update': np.int64(631),
#  'update stoptxt': np.int64(2221),
#  'pick bout': np.int64(1505),
#  'time go': np.int64(2093),
#  'call back': np.int64(185),
#  'make feel': np.int64(1180),
#  'good even': np.int64(795),
#  'hope fine': np.int64(940),
#  'wanna get': np.int64(2323),
#  'poly text': np.int64(1621),
#  'text get': np.int64(2050),
#  'st free': np.int64(1945),
#  'free tone': np.int64(629),
#  'txt stop': np.int64(2197),
#  'haha get': np.int64(859),
#  'get use': np.int64(716),
#  'hope day': np.int64(937),
#  'time place': np.int64(2099),
#  'message text': np.int64(1240),
#  'miss number': np.int64(1266),
#  'miss send': np.int64(1267),
#  'send via': np.int64(1842),
#  'via fullonsms': np.int64(2286),
#  'fullonsms com': np.int64(650),
#  'come room': np.int64(332),
#  'yan jiu': np.int64(2467),
#  'den go': np.int64(466),
#  'date service': np.int64(421),
#  'box sk': np.int64(164),
#  'dont want': np.int64(499),
#  'entry weekly': np.int64(538),
#  'text word': np.int64(2056),
#  'ur lover': np.int64(2241),
#  'pobox wq': np.int64(1608),
#  'last week': np.int64(1048),
#  'live call': np.int64(1103),
#  'contact date': np.int64(355),
#  'service enter': np.int64(1847),
#  'enter phone': np.int64(533),
#  'fancy find': np.int64(557),
#  'find call': np.int64(577),
#  'landline pobox': np.int64(1040),
#  'pobox tf': np.int64(1605),
#  'mobile number': np.int64(1280),
#  'number award': np.int64(1399),
#  'award prize': np.int64(90),
#  'call land': np.int64(204),
#  'land line': np.int64(1035),
#  'line claim': np.int64(1099),
#  'claim valid': np.int64(291),
#  'ok ok': np.int64(1428),
#  'aathi dear': np.int64(0),
#  'cos get': np.int64(370),
#  'get car': np.int64(672),
#  'wnt buy': np.int64(2420),
#  'buy bmw': np.int64(178),
#  'bmw car': np.int64(141),
#  'car urgently': np.int64(246),
#  'urgently vry': np.int64(2269),
#  'vry urgent': np.int64(2306),
#  'urgent hv': np.int64(2262),
#  'hv shortage': np.int64(956),
#  'shortage lt': np.int64(1859),
#  'gt lacs': np.int64(831),
#  'lacs source': np.int64(1033),
#  'source arng': np.int64(1928),
#  'arng dis': np.int64(64),
#  'dis amt': np.int64(476),
#  'amt lt': np.int64(40),
#  'lacs thats': np.int64(1034),
#  'thats prob': np.int64(2069),
#  'watch tv': np.int64(2352),
#  'tv lor': np.int64(2182),
#  'video camera': np.int64(2287),
#  'call call': np.int64(188),
#  'call cost': np.int64(190),
#  'cost ppm': np.int64(375),
#  'ppm ave': np.int64(1645),
#  'post bcm': np.int64(1630),
#  'ldn wc': np.int64(1063),
#  'wc xx': np.int64(2359),
#  'book ticket': np.int64(152),
#  'gt th': np.int64(838),
#  'message send': np.int64(1238),
#  'gt dollars': np.int64(826),
#  'pay lt': np.int64(1469),
#  'gt lt': np.int64(832),
#  'hi hope': np.int64(909),
#  'come get': np.int64(324),
#  'well do': np.int64(2373),
#  'hope good': np.int64(941),
#  'good day': np.int64(794),
#  'ok tell': np.int64(1434),
#  'loan purpose': np.int64(1107),
#  'purpose homeowners': np.int64(1689),
#  'homeowners tenant': np.int64(934),
#  'tenant welcome': np.int64(2042),
#  'welcome previously': np.int64(2372),
#  'previously refuse': np.int64(1663),
#  'refuse still': np.int64(1735),
#  'still help': np.int64(1961),
#  'help call': np.int64(895),
#  'free text': np.int64(626),
#  'text back': np.int64(2046),
#  'back help': np.int64(96),
#  'thank god': np.int64(2063),
#  'make love': np.int64(1182),
#  'gt time': np.int64(839),
#  'time per': np.int64(2098),
#  'per night': np.int64(1478),
#  'tenerife holiday': np.int64(2043),
#  'holiday cash': np.int64(922),
#  'cash award': np.int64(254),
#  'award call': np.int64(84),
#  'box cw': np.int64(161),
#  'cw wx': np.int64(411),
#  'wx ppm': np.int64(2460),
#  'account lt': np.int64(11),
#  'send account': np.int64(1821),
#  'account detail': np.int64(10),
#  'nyt ec': np.int64(1405),
#  'love aathi': np.int64(1138),
#  'aathi love': np.int64(1),
#  'cant wait': np.int64(244),
#  'real thing': np.int64(1717),
#  'free message': np.int64(615),
#  'message activate': np.int64(1230),
#  'text message': np.int64(2052),
#  'term condition': np.int64(2044),
#  'visit www': np.int64(2292),
#  'sorry man': np.int64(1921),
#  'sorry meet': np.int64(1922),
#  'meet call': np.int64(1215),
#  'fight world': np.int64(573),
#  'world easy': np.int64(2436),
#  'easy either': np.int64(519),
#  'either win': np.int64(525),
#  'win lose': np.int64(2395),
#  'lose bt': np.int64(1128),
#  'bt fightng': np.int64(175),
#  'fightng close': np.int64(574),
#  'close dificult': np.int64(296),
#  'dificult lose': np.int64(471),
#  'lose lose': np.int64(1129),
#  'lose win': np.int64(1133),
#  'win still': np.int64(2399),
#  'still lose': np.int64(1962),
#  'prize claim': np.int64(1672),
#  'call cs': np.int64(191),
#  'cs stop': np.int64(395),
#  'stop sms': np.int64(1978),
#  'sms ppm': np.int64(1896),
#  'bore wat': np.int64(157),
#  'pay rent': np.int64(1470),
#  'stuff like': np.int64(1986),
#  'need help': np.int64(1346),
#  'opinion jada': np.int64(1447),
#  'jada kusruthi': np.int64(990),
#  'kusruthi lovable': np.int64(1032),
#  'lovable silent': np.int64(1137),
#  'silent spl': np.int64(1866),
#  'spl character': np.int64(1943),
#  'character mature': np.int64(266),
#  'mature stylish': np.int64(1207),
#  'stylish simple': np.int64(1989),
#  'simple pls': np.int64(1868),
#  'pls reply': np.int64(1581),
#  'prabha soryda': np.int64(1651),
#  'soryda realy': np.int64(1925),
#  'realy frm': np.int64(1726),
#  'frm heart': np.int64(646),
#  'heart sory': np.int64(888),
#  'lol ok': np.int64(1113),
#  'guarantee latest': np.int64(847),
#  'latest nokia': np.int64(1058),
#  'nokia phone': np.int64(1389),
#  'phone gb': np.int64(1493),
#  'gb ipod': np.int64(658),
#  'ipod mp': np.int64(988),
#  'mp player': np.int64(1299),
#  'player prize': np.int64(1548),
#  'prize txt': np.int64(1682),
#  'word collect': np.int64(2424),
#  'collect ibhltd': np.int64(307),
#  'ibhltd ldnw': np.int64(958),
#  'ldnw mtmsgrcvd': np.int64(1066),
#  'tone reply': np.int64(2164),
#  'tone txt': np.int64(2166),
#  'http www': np.int64(954),
#  'sit night': np.int64(1874),
#  'want ask': np.int64(2325),
#  'free need': np.int64(619),
#  'need know': np.int64(1347),
#  'shall come': np.int64(1854),
#  'gonna go': np.int64(790),
#  'prize nd': np.int64(1679),
#  'nd attempt': np.int64(1335),
#  'attempt contact': np.int64(79),
#  'call box': np.int64(187),
#  'box qu': np.int64(163),
#  'merry mas': np.int64(1229),
#  'today offer': np.int64(2139),
#  'claim ur': np.int64(290),
#  'ur worth': np.int64(2259),
#  'worth discount': np.int64(2440),
#  'discount vouchers': np.int64(479),
#  'vouchers text': np.int64(2304),
#  'text yes': np.int64(2057),
#  'yes savamob': np.int64(2482),
#  'savamob member': np.int64(1781),
#  'member offer': np.int64(1227),
#  'offer mobile': np.int64(1407),
#  'mobile cs': np.int64(1275),
#  'cs sub': np.int64(396),
#  'next hrs': np.int64(1373),
#  'show un': np.int64(1862),
#  'un redeem': np.int64(2212),
#  'redeem point': np.int64(1733),
#  'point call': np.int64(1612),
#  'today sunday': np.int64(2143),
#  'sunday sunday': np.int64(1996),
#  'sunday holiday': np.int64(1995),
#  'holiday work': np.int64(925),
#  'pls give': np.int64(1574),
#  'afternoon love': np.int64(20),
#  'love go': np.int64(1141),
#  'go day': np.int64(742),
#  'passionate kiss': np.int64(1467),
#  'kiss across': np.int64(1014),
#  'across sea': np.int64(13),
#  'probably gonna': np.int64(1684),
#  'see later': np.int64(1810),
#  'later tonight': np.int64(1053),
#  'ummmmmaah many': np.int64(2211),
#  'many many': np.int64(1194),
#  'many happy': np.int64(1193),
#  'happy return': np.int64(876),
#  'return day': np.int64(1760),
#  'day dear': np.int64(426),
#  'dear sweet': np.int64(443),
#  'sweet heart': np.int64(2008),
#  'heart happy': np.int64(886),
#  'happy birthday': np.int64(873),
#  'birthday dear': np.int64(115),
#  'without lose': np.int64(2414),
#  'go college': np.int64(741),
#  'know need': np.int64(1023),
#  'sorry take': np.int64(1924),
#  'take long': np.int64(2016),
#  'every night': np.int64(547),
#  'still need': np.int64(1964),
#  'love much': np.int64(1147),
#  'barely stand': np.int64(102),
#  'fuck babe': np.int64(648),
#  'babe miss': np.int64(94),
#  'ill call': np.int64(961),
#  'go gym': np.int64(746),
#  'love smile': np.int64(1150),
#  'hope ok': np.int64(945),
#  'ok good': np.int64(1423),
#  'miss much': np.int64(1265),
#  'yar lor': np.int64(2468),
#  'wait call': np.int64(2307),
#  'call us': np.int64(230),
#  'us back': np.int64(2271),
#  'need change': np.int64(1339),
#  'new video': np.int64(1368),
#  'video phone': np.int64(2289),
#  'one day': np.int64(1439),
#  'dun thk': np.int64(512),
#  'go jazz': np.int64(750),
#  'yogasana oso': np.int64(2494),
#  'go meet': np.int64(757),
#  'ur chance': np.int64(2225),
#  'shop spree': np.int64(1857),
#  'www txt': np.int64(2458),
#  'custcare wk': np.int64(402),
#  'ppm cs': np.int64(1646),
#  'cs apply': np.int64(390),
#  'important customer': np.int64(972),
#  'service announcement': np.int64(1845),
#  'call freephone': np.int64(197),
#  'go buy': np.int64(740),
#  'send home': np.int64(1831),
#  'home first': np.int64(929),
#  'ok lor': np.int64(1427),
#  'meet lunch': np.int64(1221),
#  'wait see': np.int64(2311),
#  'see get': np.int64(1809),
#  'neva mind': np.int64(1357),
#  'get drink': np.int64(677),
#  'want come': np.int64(2326),
#  'come find': np.int64(323),
#  'latest news': np.int64(1057),
#  'news result': np.int64(1372),
#  'result daily': np.int64(1759),
#  'send get': np.int64(1828),
#  'game send': np.int64(653),
#  ...}

# %%
# bag of words but with ngrams - UNIGRAM AND BIGRAM and trigram
# create new bag of words with lemmatizer
# lemma_cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(1, 2))
lemma_cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(3, 3)) # ignoring unigram
X = lemma_cv.fit_transform(lemma_corpus).toarray()
lemma_cv.vocabulary_
# Out:
# {'free entry wkly': np.int64(496),
#  'may text fa': np.int64(998),
#  'receive entry question': np.int64(1676),
#  'question std txt': np.int64(1629),
#  'std txt rate': np.int64(1990),
#  'txt rate apply': np.int64(2180),
#  'per request melle': np.int64(1439),
#  'request melle melle': np.int64(1731),
#  'melle melle oru': np.int64(1015),
#  'melle oru minnaminunginte': np.int64(1016),
#  'oru minnaminunginte nurungu': np.int64(1392),
#  'minnaminunginte nurungu vettam': np.int64(1054),
#  'nurungu vettam set': np.int64(1330),
#  'vettam set callertune': np.int64(2335),
#  'set callertune callers': np.int64(1899),
#  'callertune callers press': np.int64(245),
#  'callers press copy': np.int64(244),
#  'press copy friends': np.int64(1585),
#  'copy friends callertune': np.int64(353),
#  'winner value network': np.int64(2440),
#  'value network customer': np.int64(2327),
#  'network customer select': np.int64(1240),
#  'select receivea prize': np.int64(1844),
#  'receivea prize reward': np.int64(1680),
#  'prize reward claim': np.int64(1606),
#  'reward claim call': np.int64(1742),
#  'claim call claim': np.int64(286),
#  'call claim code': np.int64(208),
#  'kl valid hours': np.int64(689),
#  'mobile months entitle': np.int64(1107),
#  'months entitle update': np.int64(1137),
#  'entitle update latest': np.int64(440),
#  'update latest colour': np.int64(2232),
#  'latest colour mobiles': np.int64(746),
#  'mobiles camera free': np.int64(1121),
#  'free call mobile': np.int64(490),
#  'call mobile update': np.int64(225),
#  'mobile update co': np.int64(1116),
#  'update co free': np.int64(2230),
#  'chance win cash': np.int64(271),
#  'pound txt csh': np.int64(1572),
#  'txt csh send': np.int64(2163),
#  'send cost day': np.int64(1854),
#  'tsandcs apply reply': np.int64(2143),
#  'reply hl info': np.int64(1712),
#  'urgent week free': np.int64(2301),
#  'membership prize jackpot': np.int64(1019),
#  'prize jackpot txt': np.int64(1603),
#  'txt word claim': np.int64(2186),
#  'net lccltd pobox': np.int64(1237),
#  'lccltd pobox ldnw': np.int64(758),
#  'pobox ldnw rw': np.int64(1539),
#  'try call reply': np.int64(2133),
#  'call reply sms': np.int64(237),
#  'call delivery tomorrow': np.int64(212),
#  'lt gt inch': np.int64(913),
#  'call message miss': np.int64(222),
#  'message miss call': np.int64(1028),
#  'like lt gt': np.int64(806),
#  'lt url gt': np.int64(933),
#  'congrats year special': np.int64(337),
#  'year special cinema': np.int64(2483),
#  'special cinema pass': np.int64(1973),
#  'cinema pass call': np.int64(284),
#  'pass call suprman': np.int64(1412),
#  'call suprman matrix': np.int64(239),
#  'suprman matrix starwars': np.int64(2011),
#  'matrix starwars etc': np.int64(990),
#  'starwars etc free': np.int64(1987),
#  'etc free bx': np.int64(445),
#  'free bx ip': np.int64(489),
#  'bx ip pm': np.int64(204),
#  'ip pm dont': np.int64(659),
#  'pm dont miss': np.int64(1529),
#  'sorry call later': np.int64(1965),
#  'call later meet': np.int64(221),
#  'part check iq': np.int64(1404),
#  'value customer please': np.int64(2324),
#  'customer please advise': np.int64(373),
#  'please advise follow': np.int64(1497),
#  'advise follow recent': np.int64(6),
#  'follow recent review': np.int64(484),
#  'recent review mob': np.int64(1681),
#  'review mob award': np.int64(1741),
#  'mob award bonus': np.int64(1088),
#  'award bonus prize': np.int64(84),
#  'bonus prize call': np.int64(171),
#  'today song dedicate': np.int64(2072),
#  'send ur valuable': np.int64(1879),
#  'ur valuable frnds': np.int64(2285),
#  'valuable frnds first': np.int64(2323),
#  'urgent ur award': np.int64(2300),
#  'ur award complimentary': np.int64(2239),
#  'award complimentary trip': np.int64(90),
#  'trip eurodisinc trav': np.int64(2124),
#  'trav aco entry': np.int64(2121),
#  'claim txt dis': np.int64(298),
#  'txt dis morefrmmob': np.int64(2164),
#  'morefrmmob shracomorsglsuplt ls': np.int64(1146),
#  'shracomorsglsuplt ls aj': np.int64(1931),
#  'gentleman treat dignity': np.int64(521),
#  'treat dignity respect': np.int64(2123),
#  'later network urgnt': np.int64(743),
#  'network urgnt sms': np.int64(1245),
#  'pain come back': np.int64(1397),
#  'pleasure smile pain': np.int64(1510),
#  'pain smile trouble': np.int64(1399),
#  'trouble pour like': np.int64(2126),
#  'pour like rain': np.int64(1573),
#  'like rain smile': np.int64(809),
#  'rain smile sum': np.int64(1642),
#  'becoz someone still': np.int64(130),
#  'love see smile': np.int64(885),
#  'please call customer': np.int64(1500),
#  'call customer service': np.int64(211),
#  'customer service representative': np.int64(375),
#  'service representative pm': np.int64(1895),
#  'representative pm guarantee': np.int64(1729),
#  'pm guarantee cash': np.int64(1530),
#  'guarantee cash prize': np.int64(581),
#  'ringtone wait collect': np.int64(1755),
#  'wait collect simply': np.int64(2372),
#  'password mix verify': np.int64(1414),
#  'mix verify get': np.int64(1085),
#  'verify get usher': np.int64(2332),
#  'usher britney fml': np.int64(2316),
#  'try contact last': np.int64(2134),
#  'contact last weekend': np.int64(345),
#  'last weekend draw': np.int64(738),
#  'weekend draw show': np.int64(2410),
#  'draw show prize': np.int64(421),
#  'show prize guarantee': np.int64(1928),
#  'prize guarantee call': np.int64(1602),
#  'guarantee call claim': np.int64(579),
#  'claim code valid': np.int64(290),
#  'code valid hrs': np.int64(313),
#  'valid hrs ppm': np.int64(2322),
#  'enter cabin pa': np.int64(437),
#  'cabin pa say': np.int64(205),
#  'pa say happy': np.int64(1395),
#  'say happy day': np.int64(1798),
#  'happy day boss': np.int64(595),
#  'day boss felt': np.int64(385),
#  'boss felt special': np.int64(177),
#  'felt special askd': np.int64(467),
#  'special askd lunch': np.int64(1972),
#  'askd lunch lunch': np.int64(59),
#  'lunch lunch invite': np.int64(942),
#  'lunch invite apartment': np.int64(941),
#  'invite apartment go': np.int64(655),
#  'winner specially select': np.int64(2439),
#  'specially select receive': np.int64(1979),
#  'holiday flight inc': np.int64(624),
#  'flight inc speak': np.int64(483),
#  'inc speak live': np.int64(648),
#  'speak live operator': np.int64(1970),
#  'live operator claim': np.int64(835),
#  'operator claim min': np.int64(1370),
#  'private account statement': np.int64(1592),
#  'account statement show': np.int64(4),
#  'statement show unredeemed': np.int64(1989),
#  'show unredeemed bonus': np.int64(1930),
#  'unredeemed bonus point': np.int64(2221),
#  'bonus point claim': np.int64(170),
#  'point claim call': np.int64(1549),
#  'claim call identifier': np.int64(288),
#  'call identifier code': np.int64(215),
#  'identifier code expire': np.int64(642),
#  'urgent mobile award': np.int64(2294),
#  'mobile award bonus': np.int64(1093),
#  'award bonus caller': np.int64(83),
#  'bonus caller prize': np.int64(169),
#  'caller prize final': np.int64(242),
#  'todays voda number': np.int64(2080),
#  'voda number end': np.int64(2352),
#  'number end select': np.int64(1324),
#  'end select receive': np.int64(435),
#  'select receive award': np.int64(1840),
#  'receive award match': np.int64(1671),
#  'award match please': np.int64(93),
#  'match please call': np.int64(989),
#  'please call quote': np.int64(1503),
#  'call quote claim': np.int64(235),
#  'quote claim code': np.int64(1637),
#  'claim code standard': np.int64(289),
#  'code standard rat': np.int64(312),
#  'standard rat app': np.int64(1985),
#  'wat time finish': np.int64(2396),
#  'sunshine quiz wkly': np.int64(2010),
#  'quiz wkly win': np.int64(1636),
#  'wkly win top': np.int64(2448),
#  'win top sony': np.int64(2436),
#  'top sony dvd': np.int64(2110),
#  'sony dvd player': np.int64(1964),
#  'dvd player know': np.int64(426),
#  'player know country': np.int64(1495),
#  'know country algarve': np.int64(691),
#  'algarve txt ansr': np.int64(18),
#  'txt ansr sp': np.int64(2155),
#  'ansr sp tyrone': np.int64(39),
#  'want get lay': np.int64(2388),
#  'lay tonight want': np.int64(757),
#  'tonight want real': np.int64(2105),
#  'want real dog': np.int64(2394),
#  'real dog locations': np.int64(1663),
#  'dog locations send': np.int64(414),
#  'locations send direct': np.int64(841),
#  'send direct ur': np.int64(1856),
#  'ur mob join': np.int64(2270),
#  'mob join uk': np.int64(1091),
#  'join uk largest': np.int64(668),
#  'uk largest dog': np.int64(2203),
#  'largest dog network': np.int64(733),
#  'check room befor': np.int64(280),
#  'room befor activities': np.int64(1761),
#  'netcollex ltd per': np.int64(1239),
#  'ltd per msg': np.int64(934),
#  'per msg reply': np.int64(1437),
#  'msg reply stop': np.int64(1173),
#  'reply stop end': np.int64(1721),
#  'select receive cash': np.int64(1841),
#  'receive cash holiday': np.int64(1675),
#  'cash holiday flight': np.int64(263),
#  'invite friend reply': np.int64(656),
#  'friend reply yes': np.int64(506),
#  'reply yes see': np.int64(1726),
#  'yes see www': np.int64(2495),
#  'see www sms': np.int64(1836),
#  'www sms ac': np.int64(2470),
#  'stop send stop': np.int64(1996),
#  'send stop frnd': np.int64(1870),
#  'urgent try contact': np.int64(2299),
#  'yes completely form': np.int64(2489),
#  'clark also utter': np.int64(304),
#  'also utter waste': np.int64(24),
#  'let know get': np.int64(776),
#  'lt gt worth': np.int64(929),
#  'hi speak maneesha': np.int64(613),
#  'speak maneesha like': np.int64(1971),
#  'maneesha like know': np.int64(976),
#  'like know satisfy': np.int64(805),
#  'know satisfy experience': np.int64(701),
#  'satisfy experience reply': np.int64(1786),
#  'experience reply toll': np.int64(453),
#  'reply toll free': np.int64(1723),
#  'toll free yes': np.int64(2082),
#  'service representative freephone': np.int64(1894),
#  'representative freephone pm': np.int64(1727),
#  'freephone pm guarantee': np.int64(505),
#  'settle new school': np.int64(1900),
#  'new school year': np.int64(1260),
#  'school year wishin': np.int64(1810),
#  'year wishin gr': np.int64(2485),
#  'gud mrng dear': np.int64(584),
#  'mrng dear hav': np.int64(1162),
#  'dear hav nice': np.int64(394),
#  'hav nice day': np.int64(599),
#  'get persons story': np.int64(528),
#  'send lt gt': np.int64(1865),
#  'lt gt buck': np.int64(900),
#  'refill successfully inr': np.int64(1691),
#  'lt decimal gt': np.int64(897),
#  'keralacircle prepay account': np.int64(680),
#  'prepay account balance': np.int64(1583),
#  'balance rs lt': np.int64(117),
#  'rs lt decimal': np.int64(1765),
#  'transaction id kr': np.int64(2118),
#  'kr lt gt': np.int64(713),
#  'shoot big load': np.int64(1915),
#  'big load get': np.int64(145),
#  'load get ready': np.int64(839),
#  'ah sen get': np.int64(10),
#  'sen get select': np.int64(1850),
#  'select mean good': np.int64(1839),
#  'take ur time': np.int64(2020),
#  'new mobiles must': np.int64(1254),
#  'mobiles must go': np.int64(1123),
#  'must go txt': np.int64(1204),
#  'go txt nokia': np.int64(552),
#  'txt nokia collect': np.int64(2172),
#  'nokia collect today': np.int64(1295),
#  'collect today www': np.int64(316),
#  'today www tc': np.int64(2078),
#  'www tc biz': np.int64(2471),
#  'tc biz optout': np.int64(2021),
#  'biz optout gbp': np.int64(152),
#  'optout gbp mtmsg': np.int64(1375),
#  'yes tv always': np.int64(2496),
#  'tv always available': np.int64(2147),
#  'always available work': np.int64(25),
#  'available work place': np.int64(76),
#  'name age eg': np.int64(1208),
#  'new theory argument': np.int64(1262),
#  'theory argument win': np.int64(2050),
#  'argument win situation': np.int64(44),
#  'win situation lose': np.int64(2433),
#  'situation lose person': np.int64(1943),
#  'lose person dont': np.int64(857),
#  'person dont argue': np.int64(1443),
#  'dont argue ur': np.int64(415),
#  'argue ur friends': np.int64(43),
#  'ur friends kick': np.int64(2252),
#  'friends kick amp': np.int64(509),
#  'kick amp say': np.int64(682),
#  'amp say always': np.int64(31),
#  'say always correct': np.int64(1795),
#  'secret admirer look': np.int64(1821),
#  'admirer look make': np.int64(5),
#  'look make contact': np.int64(849),
#  'make contact find': np.int64(958),
#  'contact find reveal': np.int64(344),
#  'find reveal think': np.int64(476),
#  'reveal think ur': np.int64(1739),
#  'think ur special': np.int64(2051),
#  'ur special call': np.int64(2280),
#  'bat nd innings': np.int64(120),
#  'congratulations ur award': np.int64(339),
#  'ur award cd': np.int64(2237),
#  'award cd vouchers': np.int64(88),
#  'cd vouchers gift': np.int64(269),
#  'vouchers gift guarantee': np.int64(2364),
#  'gift guarantee free': np.int64(533),
#  'guarantee free entry': np.int64(582),
#  'entry wkly draw': np.int64(444),
#  'wkly draw txt': np.int64(2447),
#  'draw txt music': np.int64(423),
#  'txt music tncs': np.int64(2169),
#  'music tncs www': np.int64(1202),
#  'tncs www ldew': np.int64(2063),
#  'www ldew com': np.int64(2467),
#  'ldew com win': np.int64(760),
#  'com win ppmx': np.int64(325),
#  'win ppmx age': np.int64(2432),
#  'ranjith cal drpd': np.int64(1647),
#  'wen ur lovable': np.int64(2418),
#  'ur lovable bcums': np.int64(2261),
#  'lovable bcums angry': np.int64(863),
#  'bcums angry wid': np.int64(127),
#  'angry wid dnt': np.int64(37),
#  'wid dnt take': np.int64(2421),
#  'dnt take seriously': np.int64(413),
#  'take seriously coz': np.int64(2019),
#  'seriously coz angry': np.int64(1885),
#  'coz angry childish': np.int64(358),
#  'angry childish true': np.int64(36),
#  'childish true way': np.int64(281),
#  'true way show': np.int64(2130),
#  'way show deep': np.int64(2402),
#  'show deep affection': np.int64(1927),
#  'deep affection care': np.int64(400),
#  'affection care luv': np.int64(7),
#  'care luv kettoda': np.int64(256),
#  'luv kettoda manda': np.int64(945),
#  'kettoda manda nice': np.int64(681),
#  'manda nice day': np.int64(975),
#  'nice day da': np.int64(1279),
#  'try contact reply': np.int64(2137),
#  'contact reply offer': np.int64(347),
#  'reply offer video': np.int64(1716),
#  'offer video handset': np.int64(1339),
#  'video handset anytime': np.int64(2339),
#  'handset anytime network': np.int64(591),
#  'anytime network mins': np.int64(41),
#  'network mins unlimited': np.int64(1243),
#  'mins unlimited text': np.int64(1063),
#  'unlimited text camcorder': np.int64(2218),
#  'text camcorder reply': np.int64(2033),
#  'camcorder reply call': np.int64(246),
#  'dun disturb liao': np.int64(425),
#  'unsubscribe text stop': np.int64(2227),
#  'night end another': np.int64(1286),
#  'end another day': np.int64(434),
#  'another day morning': np.int64(38),
#  'day morning come': np.int64(389),
#  'morning come special': np.int64(1147),
#  'come special way': np.int64(328),
#  'special way may': np.int64(1978),
#  'way may smile': np.int64(2401),
#  'may smile like': np.int64(997),
#  'smile like sunny': np.int64(1951),
#  'like sunny ray': np.int64(810),
#  'sunny ray leave': np.int64(2009),
#  'ray leave worry': np.int64(1651),
#  'leave worry blue': np.int64(774),
#  'worry blue blue': np.int64(2459),
#  'blue blue bay': np.int64(163),
#  'hmv bonus special': np.int64(616),
#  'bonus special pound': np.int64(172),
#  'special pound genuine': np.int64(1976),
#  'pound genuine hmv': np.int64(1568),
#  'genuine hmv vouchers': np.int64(523),
#  'hmv vouchers answer': np.int64(618),
#  'vouchers answer easy': np.int64(2361),
#  'answer easy question': np.int64(40),
#  'easy question play': np.int64(429),
#  'question play send': np.int64(1628),
#  'play send hmv': np.int64(1493),
#  'send hmv info': np.int64(1862),
#  'hmv info www': np.int64(617),
#  'info www percent': np.int64(651),
#  'www percent real': np.int64(2468),
#  'percent real com': np.int64(1442),
#  'life mean lot': np.int64(790),
#  'mean lot love': np.int64(1002),
#  'lot love life': np.int64(861),
#  'love life love': np.int64(876),
#  'life love people': np.int64(789),
#  'love people life': np.int64(883),
#  'people life world': np.int64(1427),
#  'life world call': np.int64(791),
#  'customer may claim': np.int64(372),
#  'may claim free': np.int64(995),
#  'claim free camera': np.int64(292),
#  'free camera phone': np.int64(493),
#  'camera phone upgrade': np.int64(251),
#  'loyalty call offer': np.int64(895),
#  'call offer end': np.int64(231),
#  'make cry end': np.int64(959),
#  'life die plz': np.int64(783),
#  'plz keep one': np.int64(1524),
#  'keep one rise': np.int64(676),
#  'one rise grave': np.int64(1364),
#  'rise grave say': np.int64(1757),
#  'say stupid miss': np.int64(1806),
#  'miss nice day': np.int64(1078),
#  'nice day bslvyl': np.int64(1278),
#  'cant pick phone': np.int64(253),
#  'pick phone right': np.int64(1474),
#  'phone right pls': np.int64(1464),
#  'right pls send': np.int64(1746),
#  'pls send message': np.int64(1520),
#  'need coffee run': np.int64(1229),
#  'run tomo believe': np.int64(1774),
#  'tomo believe time': np.int64(2083),
#  'believe time week': np.int64(133),
#  'want go meal': np.int64(2390),
#  'today accept day': np.int64(2066),
#  'accept day accept': np.int64(2),
#  'day accept brother': np.int64(384),
#  'accept brother sister': np.int64(1),
#  'brother sister lover': np.int64(199),
#  'sister lover dear': np.int64(1942),
#  'lover dear best': np.int64(890),
#  'dear best clos': np.int64(393),
#  'best clos lvblefrnd': np.int64(138),
#  'clos lvblefrnd jstfrnd': np.int64(306),
#  'lvblefrnd jstfrnd cutefrnd': np.int64(949),
#  'jstfrnd cutefrnd lifpartnr': np.int64(671),
#  'cutefrnd lifpartnr belovd': np.int64(377),
#  'lifpartnr belovd swtheart': np.int64(794),
#  'belovd swtheart bstfrnd': np.int64(135),
#  'swtheart bstfrnd rply': np.int64(2015),
#  'bstfrnd rply mean': np.int64(200),
#  'rply mean enemy': np.int64(1763),
#  'december mobile mths': np.int64(398),
#  'mobile mths entitle': np.int64(1108),
#  'mths entitle update': np.int64(1184),
#  'latest colour camera': np.int64(745),
#  'colour camera mobile': np.int64(320),
#  'camera mobile free': np.int64(249),
#  'mobile free call': np.int64(1101),
#  'babe love ya': np.int64(104),
#  'pence per minute': np.int64(1424),
#  'per minute call': np.int64(1435),
#  'minute call fix': np.int64(1066),
#  'line via access': np.int64(822),
#  'via access number': np.int64(2336),
#  'number prepayment direct': np.int64(1329),
#  'prepayment direct access': np.int64(1584),
#  'valentines day special': np.int64(2321),
#  'quiz take partner': np.int64(1634),
#  'partner trip lifetime': np.int64(1410),
#  'trip lifetime send': np.int64(2125),
#  'lifetime send go': np.int64(793),
#  'send go msg': np.int64(1861),
#  'msg rcvd custcare': np.int64(1170),
#  'today sorry day': np.int64(2073),
#  'misbehave hurt plz': np.int64(1072),
#  'plz plz slap': np.int64(1526),
#  'plz slap urself': np.int64(1527),
#  'urself bcoz ur': np.int64(2305),
#  'bcoz ur fault': np.int64(126),
#  'ur fault basically': np.int64(2248),
#  'alcohol jay try': np.int64(16),
#  'try figure much': np.int64(2139),
#  'lt gt ish': np.int64(915),
#  'ur cash balance': np.int64(2242),
#  'cash balance currently': np.int64(261),
#  'balance currently pound': np.int64(116),
#  'currently pound maximize': np.int64(370),
#  'pound maximize ur': np.int64(1569),
#  'maximize ur cash': np.int64(993),
#  'ur cash send': np.int64(2243),
#  'send cash msg': np.int64(1852),
#  'msg cc hg': np.int64(1163),
#  'cc hg suite': np.int64(266),
#  'hg suite land': np.int64(610),
#  'suite land row': np.int64(2005),
#  'land row hl': np.int64(722),
#  'offer latest motorola': np.int64(1335),
#  'latest motorola sonyericsson': np.int64(748),
#  'motorola sonyericsson nokia': np.int64(1156),
#  'nokia free bluetooth': np.int64(1298),
#  'mins txt orange': np.int64(1059),
#  'txt orange call': np.int64(2175),
#  'orange call mobileupd': np.int64(1380),
#  'call mobileupd call': np.int64(227),
#  'mobileupd call optout': np.int64(1126),
#  'boytoy geeee miss': np.int64(192),
#  'next lt gt': np.int64(1275),
#  'lt gt min': np.int64(920),
#  'much will pay': np.int64(1192),
#  'thank ringtone order': np.int64(2048),
#  'ringtone order reference': np.int64(1752),
#  'double mins txts': np.int64(419),
#  'mins txts months': np.int64(1061),
#  'txts months free': np.int64(2194),
#  'months free bluetooth': np.int64(1138),
#  'bluetooth orange available': np.int64(166),
#  'orange available sony': np.int64(1378),
#  'available sony nokia': np.int64(75),
#  'nokia motorola phone': np.int64(1303),
#  'motorola phone call': np.int64(1155),
#  'phone call mobileupd': np.int64(1454),
#  'mths half price': np.int64(1185),
#  'half price orange': np.int64(589),
#  'price orange line': np.int64(1591),
#  'orange line rental': np.int64(1382),
#  'line rental latest': np.int64(819),
#  'rental latest camera': np.int64(1703),
#  'latest camera phone': np.int64(744),
#  'camera phone free': np.int64(250),
#  'phone free phone': np.int64(1460),
#  'free phone mths': np.int64(499),
#  'phone mths call': np.int64(1463),
#  'mths call mobilesdirect': np.int64(1182),
#  'call mobilesdirect free': np.int64(226),
#  'mobilesdirect free update': np.int64(1125),
#  'free update stoptxt': np.int64(504),
#  'loxahatchee xmas tree': np.int64(893),
#  'message text miss': np.int64(1035),
#  'miss sender name': np.int64(1082),
#  'sender name miss': np.int64(1882),
#  'name miss number': np.int64(1213),
#  'miss number miss': np.int64(1079),
#  'number miss send': np.int64(1327),
#  'miss send date': np.int64(1080),
#  'send date miss': np.int64(1855),
#  'miss miss lot': np.int64(1077),
#  'miss lot thats': np.int64(1076),
#  'lot thats everything': np.int64(862),
#  'miss send via': np.int64(1081),
#  'send via fullonsms': np.int64(1880),
#  'via fullonsms com': np.int64(2337),
#  'box sk ch': np.int64(185),
#  'free entry weekly': np.int64(495),
#  'txttowin co uk': np.int64(2197),
#  'send logo ur': np.int64(1864),
#  'logo ur lover': np.int64(846),
#  'ur lover name': np.int64(2263),
#  'lover name join': np.int64(891),
#  'name join heart': np.int64(1211),
#  'txt love name': np.int64(2167),
#  'love name name': np.int64(882),
#  'name name mobno': np.int64(1215),
#  'name mobno eg': np.int64(1214),
#  'mobno eg love': np.int64(1129),
#  'love adam eve': np.int64(866),
#  'yahoo pobox wq': np.int64(2480),
#  'pobox wq txtno': np.int64(1544),
#  'contact date service': np.int64(343),
#  'date service enter': np.int64(382),
#  'service enter phone': np.int64(1891),
#  'phone fancy find': np.int64(1457),
#  'fancy find call': np.int64(456),
#  'find call landline': np.int64(472),
#  'call landline pobox': np.int64(220),
#  'landline pobox tf': np.int64(731),
#  'urgent mobile number': np.int64(2295),
#  'mobile number award': np.int64(1110),
#  'number award prize': np.int64(1322),
#  'award prize guarantee': np.int64(96),
#  'guarantee call land': np.int64(580),
#  'call land line': np.int64(217),
#  'land line claim': np.int64(719),
#  'line claim valid': np.int64(814),
#  'claim valid hrs': np.int64(301),
#  'wnt buy bmw': np.int64(2449),
#  'buy bmw car': np.int64(203),
#  'bmw car urgently': np.int64(167),
#  'car urgently vry': np.int64(255),
#  'urgently vry urgent': np.int64(2302),
#  'vry urgent hv': np.int64(2368),
#  'urgent hv shortage': np.int64(2291),
#  'hv shortage lt': np.int64(638),
#  'shortage lt gt': np.int64(1924),
#  'lt gt lacs': np.int64(916),
#  'gt lacs source': np.int64(573),
#  'lacs source arng': np.int64(717),
#  'source arng dis': np.int64(1969),
#  'arng dis amt': np.int64(45),
#  'dis amt lt': np.int64(407),
#  'amt lt gt': np.int64(35),
#  'gt lacs thats': np.int64(574),
#  'lacs thats prob': np.int64(718),
#  'watch tv lor': np.int64(2400),
#  'nokia video camera': np.int64(1308),
#  'video camera phone': np.int64(2338),
#  'phone call call': np.int64(1453),
#  'ppm ave call': np.int64(1576),
#  'ave call mins': np.int64(77),
#  'mins vary mobiles': np.int64(1064),
#  'vary mobiles close': np.int64(2329),
#  'mobiles close post': np.int64(1122),
#  'post bcm ldn': np.int64(1563),
#  'bcm ldn wc': np.int64(122),
#  'ldn wc xx': np.int64(761),
#  'lt gt th': np.int64(925),
#  'lt gt dollars': np.int64(907),
#  'pay lt gt': np.int64(1418),
#  'lt gt lt': np.int64(918),
#  'gt lt gt': np.int64(575),
#  'yes really great': np.int64(2493),
#  'really great bhaji': np.int64(1666),
#  'bhaji tell kallis': np.int64(144),
#  'kallis best cricketer': np.int64(673),
#  'best cricketer sachin': np.int64(139),
#  'sachin world tough': np.int64(1775),
#  'loan purpose homeowners': np.int64(840),
#  'purpose homeowners tenant': np.int64(1622),
#  'homeowners tenant welcome': np.int64(627),
#  'tenant welcome previously': np.int64(2029),
#  'welcome previously refuse': np.int64(2415),
#  'previously refuse still': np.int64(1588),
#  'refuse still help': np.int64(1692),
#  'still help call': np.int64(1991),
#  'help call free': np.int64(608),
#  'call free text': np.int64(213),
#  'free text back': np.int64(501),
#  'text back help': np.int64(2032),
#  'make oreo truffles': np.int64(963),
#  'miss ya need': np.int64(1083),
#  'ya need ya': np.int64(2478),
#  'need ya want': np.int64(1234),
#  'ya want ya': np.int64(2479),
#  'ya love ya': np.int64(2477),
#  'orange customer may': np.int64(1381),
#  'phone upgrade loyalty': np.int64(1466),
#  'upgrade loyalty call': np.int64(2233),
#  'make love lt': np.int64(962),
#  'love lt gt': np.int64(879),
#  'lt gt time': np.int64(926),
#  'gt time per': np.int64(578),
#  'time per night': np.int64(2058),
#  'notice collect tenerife': np.int64(1315),
#  'tenerife holiday cash': np.int64(2030),
#  'award call landline': np.int64(86),
#  'landline tcs sae': np.int64(732),
#  'sae box cw': np.int64(1777),
#  'box cw wx': np.int64(183),
#  'cw wx ppm': np.int64(378),
#  'transfer lt gt': np.int64(2120),
#  'account lt gt': np.int64(3),
#  'send account detail': np.int64(1851),
#  'love aathi love': np.int64(865),
#  'aathi love lot': np.int64(0),
#  'message activate free': np.int64(1024),
#  'free text message': np.int64(502),
#  'message reply message': np.int64(1031),
#  'reply message word': np.int64(1715),
#  'message word free': np.int64(1036),
#  'visit www com': np.int64(2350),
#  'sorry meet call': np.int64(1966),
#  'meet call later': np.int64(1008),
#  'fight world easy': np.int64(468),
#  'world easy either': np.int64(2456),
#  'easy either win': np.int64(428),
#  'either win lose': np.int64(433),
#  'win lose bt': np.int64(2430),
#  'lose bt fightng': np.int64(854),
#  'bt fightng close': np.int64(201),
#  'fightng close dificult': np.int64(469),
#  'close dificult lose': np.int64(307),
#  'dificult lose lose': np.int64(405),
#  'lose lose win': np.int64(856),
#  'lose win still': np.int64(859),
#  'win still lose': np.int64(2434),
#  'prize claim call': np.int64(1595),
#  'claim call cs': np.int64(287),
#  'call cs stop': np.int64(209),
#  'cs stop sms': np.int64(368),
#  'stop sms ppm': np.int64(1997),
#  'opinion jada kusruthi': np.int64(1372),
#  'jada kusruthi lovable': np.int64(662),
#  'kusruthi lovable silent': np.int64(715),
#  'lovable silent spl': np.int64(864),
#  'silent spl character': np.int64(1936),
#  'spl character mature': np.int64(1980),
#  'character mature stylish': np.int64(273),
#  'mature stylish simple': np.int64(991),
#  'stylish simple pls': np.int64(2004),
#  'simple pls reply': np.int64(1938),
#  'prabha soryda realy': np.int64(1581),
#  'soryda realy frm': np.int64(1968),
#  'realy frm heart': np.int64(1668),
#  'frm heart sory': np.int64(513),
#  'guarantee latest nokia': np.int64(583),
#  'latest nokia phone': np.int64(750),
#  'nokia phone gb': np.int64(1305),
#  'phone gb ipod': np.int64(1461),
#  'gb ipod mp': np.int64(519),
#  'ipod mp player': np.int64(660),
#  'mp player prize': np.int64(1160),
#  'player prize txt': np.int64(1496),
#  'prize txt word': np.int64(1608),
#  'txt word collect': np.int64(2187),
#  'word collect ibhltd': np.int64(2451),
#  'collect ibhltd ldnw': np.int64(315),
#  'ibhltd ldnw mtmsgrcvd': np.int64(640),
#  'shall come get': np.int64(1908),
#  'caller prize nd': np.int64(243),
#  'prize nd attempt': np.int64(1605),
#  'nd attempt contact': np.int64(1223),
#  'attempt contact call': np.int64(66),
#  'contact call box': np.int64(340),
#  'call box qu': np.int64(207),
#  'today offer claim': np.int64(2071),
#  'offer claim ur': np.int64(1333),
#  'claim ur worth': np.int64(300),
#  'ur worth discount': np.int64(2287),
#  'worth discount vouchers': np.int64(2460),
#  'discount vouchers text': np.int64(409),
#  'vouchers text yes': np.int64(2365),
#  'text yes savamob': np.int64(2038),
#  'yes savamob member': np.int64(2494),
#  'savamob member offer': np.int64(1791),
#  'member offer mobile': np.int64(1017),
#  'offer mobile cs': np.int64(1336),
#  'mobile cs sub': np.int64(1098),
#  'statement show un': np.int64(1988),
#  'show un redeem': np.int64(1929),
#  'un redeem point': np.int64(2212),
#  'redeem point call': np.int64(1686),
#  'point call identifier': np.int64(1548),
#  'today sunday sunday': np.int64(2074),
#  'sunday sunday holiday': np.int64(2008),
#  'sunday holiday work': np.int64(2007),
#  'good afternoon love': np.int64(559),
#  'afternoon love go': np.int64(8),
#  'love go day': np.int64(874),
#  'passionate kiss across': np.int64(1413),
#  'kiss across sea': np.int64(687),
#  'ummmmmaah many many': np.int64(2211),
#  'many many happy': np.int64(979),
#  'many happy return': np.int64(977),
#  'happy return day': np.int64(597),
#  'return day dear': np.int64(1734),
#  'day dear sweet': np.int64(386),
#  'dear sweet heart': np.int64(395),
#  'sweet heart happy': np.int64(2013),
#  'heart happy birthday': np.int64(603),
#  'happy birthday dear': np.int64(594),
#  'stop txt stop': np.int64(1999),
#  'love much barely': np.int64(881),
#  'much barely stand': np.int64(1188),
#  'miss already know': np.int64(1073),
#  'cash prize claim': np.int64(264),
#  'new video phone': np.int64(1266),
#  'ur chance win': np.int64(2244),
#  'shop spree txt': np.int64(1920),
#  'txt shop www': np.int64(2182),
#  'shop www txt': np.int64(1922),
#  'txt shop com': np.int64(2181),
#  'shop com custcare': np.int64(1916),
#  'award call line': np.int64(87),
#  'line close cost': np.int64(815),
#  'ppm cs apply': np.int64(1577),
#  'important customer service': np.int64(645),
#  'customer service announcement': np.int64(374),
#  'service announcement call': np.int64(1886),
#  'cant wait see': np.int64(254),
#  'latest news result': np.int64(749),
#  'news result daily': np.int64(1273),
#  'valentine game send': np.int64(2318),
#  'send dis msg': np.int64(1857),
#  'msg ur friends': np.int64(1174),
#  'ur friends answer': np.int64(2250),
#  'someone really love': np.int64(1962),
#  'really love ques': np.int64(1667),
#  'love ques colour': np.int64(884),
#  'ques colour suit': np.int64(1624),
#  'well take care': np.int64(2416),
#  'happy valentines day': np.int64(598),
#  'get lt gt': np.int64(525),
#  'may pub later': np.int64(996),
#  'new textbuddy chat': np.int64(1261),
#  'ur area free': np.int64(2235),
#  'receive search postcode': np.int64(1678),
#  'search postcode gaytextbuddy': np.int64(1820),
#  'postcode gaytextbuddy com': np.int64(1566),
#  'txt one name': np.int64(2174),
#  'todays vodafone number': np.int64(2081),
#  'vodafone number end': np.int64(2354),
#  'receive award number': np.int64(1672),
#  'award number match': np.int64(94),
#  'number match call': np.int64(1326),
#  'match call receive': np.int64(988),
#  'hi hi hi': np.int64(612),
#  'dear voucher holder': np.int64(396),
#  'voucher holder claim': np.int64(2360),
#  'holder claim weeks': np.int64(621),
#  'claim weeks offer': np.int64(302),
#  'weeks offer pc': np.int64(2414),
#  'go http www': np.int64(545),
#  'http www tlp': np.int64(636),
#  'www tlp co': np.int64(2472),
#  'tlp co uk': np.int64(2061),
#  'uk expressoffer ts': np.int64(2200),
#  'ts cs apply': np.int64(2141),
#  'askd question hours': np.int64(60),
#  'question hours answer': np.int64(1627),
#  'nice ready thursday': np.int64(1282),
#  'watch cartoon listen': np.int64(2398),
#  'cartoon listen music': np.int64(258),
#  'listen music amp': np.int64(828),
#  'music amp eve': np.int64(1199),
#  'amp eve go': np.int64(27),
#  'eve go temple': np.int64(446),
#  'go temple amp': np.int64(551),
#  'temple amp church': np.int64(2027),
#  'rstm sw ss': np.int64(1767),
#  'sea lay rock': np.int64(1816),
#  'lay rock rock': np.int64(756),
#  'rock rock envelope': np.int64(1760),
#  'rock envelope envelope': np.int64(1759),
#  'paper paper word': np.int64(1401),
#  'go home first': np.int64(543),
#  'lt gt way': np.int64(928),
#  'please call immediately': np.int64(1501),
#  'call immediately urgent': np.int64(216),
#  'immediately urgent message': np.int64(644),
#  'urgent message wait': np.int64(2293),
#  'professors wer calld': np.int64(1612),
#  'askd sit aeroplane': np.int64(61),
#  'plane ws make': np.int64(1488),
#  'make students dey': np.int64(965),
#  'plane bt didnt': np.int64(1487),
#  'move say make': np.int64(1158),
#  'say make students': np.int64(1802),
#  'also know lunch': np.int64(21),
#  'know lunch menu': np.int64(698),
#  'lunch menu da': np.int64(943),
#  'menu da know': np.int64(1020),
#  'urgent nd attempt': np.int64(2297),
#  'contact call csbcm': np.int64(341),
#  'call csbcm wc': np.int64(210),
#  'csbcm wc xx': np.int64(369),
#  'wc xx callcost': np.int64(2404),
#  'ppm mobilesvary max': np.int64(1579),
#  'prize claim yr': np.int64(1597),
#  'claim yr prize': np.int64(303),
#  'yr prize call': np.int64(2498),
#  'prize call customer': np.int64(1594),
#  'leave qatar tonite': np.int64(773),
#  'customer loyalty offer': np.int64(371),
#  'loyalty offer new': np.int64(896),
#  'offer new nokia': np.int64(1337),
#  'new nokia mobile': np.int64(1257),
#  'nokia mobile txtauction': np.int64(1302),
#  'mobile txtauction txt': np.int64(1114),
#  'txtauction txt word': np.int64(2190),
#  'txt word start': np.int64(2189),
#  'word start get': np.int64(2453),
#  'take good care': np.int64(2016),
#  'best mobile content': np.int64(140),
#  'mobile content service': np.int64(1096),
#  'service uk per': np.int64(1897),
#  'send stop helpline': np.int64(1871),
#  'next week give': np.int64(1276),
#  'service announcement premier': np.int64(1887),
#  'wish family merry': np.int64(2441),
#  'family merry mas': np.int64(455),
#  'merry mas happy': np.int64(1022),
#  'mas happy new': np.int64(985),
#  'happy new year': np.int64(596),
#  'new year advance': np.int64(1268),
#  'ur award city': np.int64(2238),
#  'award city break': np.int64(89),
#  'city break could': np.int64(285),
#  'break could win': np.int64(198),
#  'could win summer': np.int64(356),
#  'win summer shop': np.int64(2435),
#  'summer shop spree': np.int64(2006),
#  'shop spree every': np.int64(1919),
#  'spree every wk': np.int64(1981),
#  'every wk txt': np.int64(451),
#  'wk txt store': np.int64(2446),
#  'txt store skilgme': np.int64(2184),
#  'store skilgme tscs': np.int64(2000),
#  'skilgme tscs winawk': np.int64(1946),
#  'tscs winawk age': np.int64(2144),
#  'winawk age perwksub': np.int64(2438),
#  'lt gt minutes': np.int64(922),
#  'txt back name': np.int64(2156),
#  'back name age': np.int64(106),
#  'call national rate': np.int64(229),
#  'ok msg leave': np.int64(1353),
#  'msg leave house': np.int64(1166),
#  'last chance claim': np.int64(734),
#  'chance claim ur': np.int64(270),
#  'discount vouchers today': np.int64(410),
#  'vouchers today text': np.int64(2366),
#  'today text shop': np.int64(2075),
#  'shop savamob offer': np.int64(1918),
#  'savamob offer mobile': np.int64(1792),
#  'mobile cs savamob': np.int64(1097),
#  'cs savamob pobox': np.int64(367),
#  'savamob pobox uz': np.int64(1793),
#  'pobox uz sub': np.int64(1542),
#  'lt time gt': np.int64(932),
#  'free st week': np.int64(500),
#  'st week nokia': np.int64(1984),
#  'week nokia tone': np.int64(2407),
#  'nokia tone ur': np.int64(1307),
#  'tone ur mobile': np.int64(2104),
#  'ur mobile every': np.int64(2272),
#  'mobile every week': np.int64(1100),
#  'every week txt': np.int64(450),
#  'week txt nokia': np.int64(2409),
#  'txt nokia get': np.int64(2173),
#  'nokia get txting': np.int64(1299),
#  'get txting tell': np.int64(530),
#  'txting tell ur': np.int64(2192),
#  'tell ur mat': np.int64(2024),
#  'ur mat www': np.int64(2267),
#  'mat www getzed': np.int64(987),
#  'www getzed co': np.int64(2466),
#  'getzed co uk': np.int64(532),
#  'co uk pobox': np.int64(311),
#  'uk pobox wq': np.int64(2207),
#  'pobox wq norm': np.int64(1543),
#  'wq norm tone': np.int64(2461),
#  'award even cashto': np.int64(92),
#  'claim ur award': np.int64(299),
#  'ur award call': np.int64(2236),
#  'award call free': np.int64(85),
#  'ur award either': np.int64(2240),
#  'award either cd': np.int64(91),
#  'either cd gift': np.int64(432),
#  'cd gift vouchers': np.int64(268),
#  'gift vouchers free': np.int64(536),
#  'vouchers free entry': np.int64(2363),
#  'entry weekly draw': np.int64(443),
#  'weekly draw txt': np.int64(2413),
#  'ok take care': np.int64(1357),
#  'text credit pls': np.int64(2034),
#  'credit pls goto': np.int64(363),
#  'pls goto www': np.int64(1516),
#  'goto www comuk': np.int64(565),
#  'www comuk net': np.int64(2465),
#  'comuk net login': np.int64(335),
#  'net login qxj': np.int64(1238),
#  'login qxj unsubscribe': np.int64(844),
#  'qxj unsubscribe stop': np.int64(1639),
#  'unsubscribe stop extra': np.int64(2226),
#  'stop extra charge': np.int64(1995),
#  'extra charge help': np.int64(454),
#  'charge help comuk': np.int64(274),
#  'help comuk cm': np.int64(609),
#  'comuk cm ae': np.int64(334),
#  'alfie moon children': np.int64(17),
#  'moon children need': np.int64(1141),
#  'children need song': np.int64(283),
#  'need song ur': np.int64(1232),
#  'song ur mob': np.int64(1963),
#  'ur mob tell': np.int64(2271),
#  'mob tell ur': np.int64(1092),
#  'tell ur txt': np.int64(2025),
#  'ur txt tone': np.int64(2284),
#  'txt tone charity': np.int64(2185),
#  'tone charity nokias': np.int64(2089),
#  'charity nokias poly': np.int64(276),
#  'nokias poly charity': np.int64(1309),
#  'poly charity polys': np.int64(1554),
#  'charity polys zed': np.int64(277),
#  'polys zed profit': np.int64(1560),
#  'zed profit charity': np.int64(2499),
#  'hahaha use brain': np.int64(587),
#  'use brain dear': np.int64(2310),
#  'secret admirer reveal': np.int64(1822),
#  'reveal think special': np.int64(1738),
#  'opt reply reveal': np.int64(1373),
#  'reply reveal stop': np.int64(1718),
#  'reveal stop per': np.int64(1737),
#  'per msg recd': np.int64(1436),
#  'msg recd cust': np.int64(1172),
#  'recd cust care': np.int64(1669),
#  'offer pc please': np.int64(1338),
#  'pc please go': np.int64(1421),
#  'please go http': np.int64(1505),
#  ...}
